# %%
import numpy as np
import pandas as pd
import os

import imageio
import geopandas
from shapely.geometry import Point, Polygon

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
import matplotlib.patches as mpatches
import seaborn as sns
# %matplotlib inline

# %%
france = geopandas.read_file('../mount/data/gadm36_FRA_shp/gadm36_FRA_0.shp')

fig, ax = plt.subplots(1)
france.plot(ax=ax)
plt.show()

# %%
france
# Out:
#   GID_0  NAME_0                                           geometry
# 0   FRA  France  MULTIPOLYGON (((9.25764 41.34903, 9.25764 41.3...

# %%
france_geom = france.iloc[0]['geometry']

# %%
france_geom.bounds
# Out:
# (-5.14375114, 41.33375168, 9.56041622, 51.08939743)

# %%
n_samples = 8000
points = []
minx, miny, maxx, maxy = france_geom.bounds
print_every = 100

while len(points) < n_samples:

    lat = np.random.rand() * (maxy - miny) + miny
    lon = np.random.rand() * (maxx - minx) + minx

    point = Point([lon, lat])

    if point.within(france_geom):
        points.append([lon, lat])
        
    if len(points) % print_every == 0:
        print(len(points))
# Out:
# 0
# 0
# 0
# 0
# 0
# 100
# 200
# 300
# 300
# 300
# 400
# 400
# 400
# 400
# 400
# 500
# 500
# 500
# 600
# 600
# 700
# 700
# 700
# 700
# 800
# 900
# 1000
# 1100
# 1100
# 1200
# 1200
# 1200
# 1200
# 1200
# 1300
# 1300
# 1300
# 1400
# 1500
# 1600
# 1600
# 1700
# 1700
# 1700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-bbacaf9802c7> in <module>
#      11     point = Point([lon, lat])
#      12
# ---> 13     if point.within(france_geom):
#      14         points.append([lon, lat])
#      15
#
# ~/anaconda3/envs/geopython/lib/python3.7/site-packages/shapely/geometry/base.py in within(self, other)
#     721     def within(self, other):
#     722         """Returns True if geometry is within the other, else False"""
# --> 723         return bool(self.impl['within'](self, other))
#     724
#     725     def equals_exact(self, other, tolerance):
#
# ~/anaconda3/envs/geopython/lib/python3.7/site-packages/shapely/predicates.py in __call__(self, this, other, *args)
#      13         self._validate(other, stop_prepared=True)
#      14         try:
# ---> 15             return self.fn(this._geom, other._geom, *args)
#      16         except PredicateError as err:
#      17             # Dig deeper into causes of errors.
#
# ~/anaconda3/envs/geopython/lib/python3.7/site-packages/shapely/geos.py in errcheck_predicate(result, func, argtuple)
#     543
#     544
# --> 545 def errcheck_predicate(result, func, argtuple):
#     546     """Result is 2 on exception, 1 on True, 0 on False"""
#     547     if result == 2:
#
# KeyboardInterrupt:

# %%
points = np.array(points)

fig, ax = plt.subplots(1, figsize=(9,10))
france.plot(ax=ax, edgecolor='black', color='#fff0d1')
plt.scatter(points[:,0], points[:,1], alpha=0.3, color='C1', s=2)
plt.show()

# %%
samples = pd.DataFrame(points, columns=['min_lon', 'min_lat'])
samples['image_id'] = ['testRun_' + str(x).zfill(5) for x in np.arange(len(points))]

# %%
samples['max_lon'] = samples['min_lon'] + 1./(111111. * np.cos(samples['min_lat'])) * 300 * 3
samples['max_lat'] = samples['min_lat'] + 1./111111. * 300 * 3

# %%
samples
# Out:
#        min_lon    min_lat       image_id   max_lon    max_lat
# 0    -0.965665  43.926856  testRun_00000 -0.957553  43.934956
# 1     1.885206  47.407555  testRun_00001  1.876769  47.415655
# 2     6.046367  43.288829  testRun_00002  6.056900  43.296929
# 3     5.388776  49.402383  testRun_00003  5.401236  49.410483
# 4     3.564963  48.270453  testRun_00004  3.545285  48.278553
# ...        ...        ...            ...       ...        ...
# 1761  0.836600  46.753352  testRun_01761  0.827910  46.761452
# 1762 -0.173732  47.364550  testRun_01762 -0.182073  47.372650
# 1763  2.344077  50.077835  testRun_01763  2.352322  50.085935
# 1764  7.111034  48.778746  testRun_01764  7.207508  48.786846
# 1765  7.680272  48.718674  testRun_01765  8.017975  48.726774
#
# [1766 rows x 5 columns]

# %%
samples[['image_id', 'min_lon', 'min_lat', 'max_lon', 'max_lat']].to_csv(
#     '../mount/data/raw_data/France_samples_latlon_8000.csv',
    '../data/planet/france/bbox_test.csv', index=False)

# %%
A = np.array([[2,4,2],
              [1,3,7],
              [0,7,3]])
B = np.array([[1,9,5],
              [3,0,6],
              [2,4,8]])
np.matmul(A,B)
# Out:
# array([[18, 26, 50],
#        [24, 37, 79],
#        [27, 12, 66]])

# %% [markdown]
# # Save Han and Burak's data as 256x256 px

# %%
base_path = '../data/planet/france/'
folders = ['april', 'january', 'october', 'labels']
size = 256

for i, folder in enumerate(folders):
    new_folder = folder + '_{}x{}'.format(size, size)
    if not os.path.exists(os.path.join(base_path, new_folder)):
        os.makedirs(os.path.join(base_path, new_folder))
        
    images = os.listdir(os.path.join(base_path, folder))
    
    for image in images:
        img = imageio.imread(os.path.join(base_path, folder, image))
        
        img = img[:size, :size]
        imageio.imwrite(os.path.join(base_path, new_folder, image), img)
