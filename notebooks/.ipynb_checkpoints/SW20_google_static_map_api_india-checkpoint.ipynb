# %%
import requests
import sys
import os
import json
import numpy as np
import pandas as pd
import imageio
from datetime import datetime, date, timedelta
import matplotlib.pyplot as plt
# %matplotlib inline

import hashlib
import hmac
import base64
import urllib.parse as urlparse

# %% [markdown]
# # Google Static Maps API for Submission Filtering

# %% [markdown]
# This notebook uses the Google Static Maps API to download satellite images at Plantix submission locations in Maharashtra.

# %%
# API key
api_key = 'AIzaSyCIzApnervVJRFp6gF16vJYBlL6zpuSbY8'

# Secret
with open('../data/credentials.txt') as file:
    secret = file.read()
secret = secret.strip('\n')

# base URL to add parameters to
url = "https://maps.googleapis.com/maps/api/staticmap?"

# %%
def latlon_to_box(lat, lon, dx=10, dy=10):
    r_earth = 6371000
    y1 = lat - (dy / r_earth) * (180 / np.pi)
    x1 = lon - (dx / r_earth) * (180 / np.pi) / np.cos(lat * np.pi / 180)
    y2 = lat + (dy / r_earth) * (180 / np.pi)
    x2 = lon + (dx / r_earth) * (180 / np.pi) / np.cos(lat * np.pi / 180)
    return y1, x1, y2, x2

# %%
def sign_url(input_url=None, secret=None):
    """ Sign a request URL with a URL signing secret.
      Usage:
      signed_url = sign_url(input_url=my_url, secret=SECRET)
      Args:
      input_url - The URL to sign
      secret    - Your URL signing secret
      Returns:
      The signed request URL
  """

    if not input_url or not secret:
        raise Exception("Both input_url and secret are required")

    url = urlparse.urlparse(input_url)

    # We only need to sign the path+query part of the string
    url_to_sign = url.path + "?" + url.query

    # Decode the private key into its binary format
    # We need to decode the URL-encoded private key
    decoded_key = base64.urlsafe_b64decode(secret)

    # Create a signature using the private key and the URL-encoded
    # string using HMAC SHA1. This signature will be binary.
    signature = hmac.new(decoded_key, str.encode(url_to_sign), hashlib.sha1)

    # Encode the binary signature into base64 for use within a URL
    encoded_signature = base64.urlsafe_b64encode(signature.digest())

    original_url = url.scheme + "://" + url.netloc + url.path + "?" + url.query

    # Return signed URL
    return original_url + "&signature=" + encoded_signature.decode()

# %% [markdown]
# ## All samples

# %%
# old data
with open('../mount/raw_data/relabelled_maharashtra.json') as f:
    j = json.load(f)
maharashtra = pd.DataFrame(j)

# old old data
# with open('../mount/raw_data/Maharashtra.json') as f:
#     j = json.load(f)
# maharashtra_old = pd.DataFrame(j)

maharashtra['unique_id'] = np.array(['maharashtra_'+x.zfill(5) for x in np.arange(maharashtra.shape[0]).astype(str)])
maharashtra['datetime'] = maharashtra['timestamp'].apply(lambda x: datetime.fromtimestamp(int(x) / 1000))

# maharashtra.to_csv('../data/maharashtra_dataset.csv', index=False)

# %%
# new extended data
with open('../mount/raw_data/Maharashtra_crop_extend.json') as f:
    j = json.load(f)
new_data = pd.DataFrame(j)

new_data.loc[:,'latitude'] = new_data['location'].map(lambda x: x['coordinates'][1])
new_data.loc[:,'longitude'] = new_data['location'].map(lambda x: x['coordinates'][0])

# %%
# loop over indices of dataframe
for idx in range(1000):
    
    # center defines the center of the map, equidistant from all edges of the map
    lat = maharashtra.iloc[idx]['latitude']
    lon = maharashtra.iloc[idx]['longitude']
    center = "{},{}".format(lat, lon)

    # zoom defines the zoom level of the map (0=whole world, 22=building-level)
    zoom = 19

    # size defines the coverage area of the map
    # the max is 640x640. pretrained models take 224x224 as input
    pixels = 500
    size = "{}x{}".format(pixels, pixels)

    # image format can be png (8-bit is default), gif, or jpg
    img_format = "jpg"

    # draw a 10m-by-10m box to mark Sentinel-2 pixel
    weight = 4
    box_y1, box_x1, box_y2, box_x2 = latlon_to_box(lat, lon, dx=5, dy=5)
    path = "color:0xff0000ff|weight:{}|{},{}|{},{}|{},{}|{},{}|{},{}".format(weight,
                                                                             box_y1, box_x1,
                                                                             box_y1, box_x2,
                                                                             box_y2, box_x2,
                                                                             box_y2, box_x1,
                                                                             box_y1, box_x1)

    # get method of requests module returns response object
    r = requests.get(url + 
                     "center=" + center +
                     "&zoom=" + str(zoom) +
                     "&size=" + size +
                     "&maptype=satellite" +
                     "&format=" + img_format +
                     "&path=" + path +
                     "&key=" + api_key
                    )
    
    # write response to a file
    img_name = maharashtra.iloc[idx]['unique_id'] + '.' + img_format
    with open('../data/static_maps/{}'.format(img_name), 'wb') as f:
        f.write(r.content)

# %%
im = imageio.imread('../data/static_maps/maharashtra_0005.jpg')
fig, ax = plt.subplots(1, figsize=(4,4))
plt.imshow(im)
plt.show()

# %%
im = imageio.imread('../data/test_img.png')
fig, ax = plt.subplots(1, figsize=(4,4))
plt.imshow(im)
plt.show()

# %%
im = imageio.imread('../data/test_img.png')
fig, ax = plt.subplots(1, figsize=(4,4))
plt.imshow(im[138:362,138:362])
plt.show()

# %% [markdown]
# ## For in-field labeling (uniformly sampled n=500)

# %%
# API key
api_key = 'AIzaSyCIzApnervVJRFp6gF16vJYBlL6zpuSbY8'

# base URL to add parameters to
url = "https://maps.googleapis.com/maps/api/staticmap?"

# dataframe of points to label
df = pd.read_csv('../data/maharashtra_infield_uniform_sample_test100.csv')

# directory to save images
img_dir = '../data/static_maps/unlabeled/'

# %%
# loop over indices of dataframe
for idx in range(df.shape[0]):
    
    # center defines the center of the map, equidistant from all edges of the map
    lat = df.iloc[idx]['latitude']
    lon = df.iloc[idx]['longitude']
    center = "{},{}".format(lat, lon)
    
    # zoom defines the zoom level of the map (0=whole world, 22=building-level)
    zoom = 19

    # size defines the coverage area of the map
    # the max is 640x640. pretrained models take 224x224 as input
    pixels = 500
    size = "{}x{}".format(pixels, pixels)

    # image format can be png (8-bit is default), gif, or jpg
    img_format = "jpg"

    # draw a 10m-by-10m box to mark Sentinel-2 pixel
    weight = 4
    box_y1, box_x1, box_y2, box_x2 = latlon_to_box(lat, lon, dx=5, dy=5)
    path = "color:0xff0000ff|weight:{}|{},{}|{},{}|{},{}|{},{}|{},{}".format(weight,
                                                                             box_y1, box_x1,
                                                                             box_y1, box_x2,
                                                                             box_y2, box_x2,
                                                                             box_y2, box_x1,
                                                                             box_y1, box_x1)
    
    # unique_id to identify the sample
    unique_id = df.iloc[idx]['unique_id']
    if unique_id + '.' + img_format in os.listdir(img_dir):
        continue # don't pull images that have already been pulled

    # get method of requests module returns response object
    r = requests.get(url + 
                     "center=" + center +
                     "&zoom=" + str(zoom) +
                     "&size=" + size +
                     "&maptype=satellite" +
                     "&format=" + img_format +
                     "&path=" + path +
                     "&key=" + api_key
                    )
    
    # write response to a file
    img_name = unique_id + '.' + img_format
    with open(os.path.join(img_dir, img_name), 'wb') as f:
        f.write(r.content)
        
    if idx % 10 == 0:
        print(idx)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90

# %% [markdown]
# ## All remaining images

# %%
# API key
api_key = 'AIzaSyCIzApnervVJRFp6gF16vJYBlL6zpuSbY8'

# base URL to add parameters to
url = "https://maps.googleapis.com/maps/api/staticmap?"

# dataframe of points to label
train1 = pd.read_csv('../data/maharashtra_infield_uniform_sample_train500_1.csv')
train2 = pd.read_csv('../data/maharashtra_infield_uniform_sample_train500_2.csv')
val = pd.read_csv('../data/maharashtra_infield_uniform_sample_val100.csv')
labeled = pd.concat([train1, train2, val]).reset_index(drop=True)

# directory to save images
img_dir = '../data/static_maps/unlabeled/'

# already downloaded
already_downloaded = os.listdir(img_dir)

# loop over indices of dataframe
for idx in range(50000, maharashtra.shape[0]):
    
    # center defines the center of the map, equidistant from all edges of the map
    lat = maharashtra.iloc[idx]['latitude']
    lon = maharashtra.iloc[idx]['longitude']
    center = "{},{}".format(lat, lon)

    # zoom defines the zoom level of the map (0=whole world, 22=building-level)
    zoom = 19

    # size defines the coverage area of the map
    # the max is 640x640. pretrained models take 224x224 as input
    pixels = 500
    size = "{}x{}".format(pixels, pixels)

    # image format can be png (8-bit is default), gif, or jpg
    img_format = "jpg"

    # draw a 10m-by-10m box to mark Sentinel-2 pixel
    weight = 4
    box_y1, box_x1, box_y2, box_x2 = latlon_to_box(lat, lon, dx=5, dy=5)
    path = "color:0xff0000ff|weight:{}|{},{}|{},{}|{},{}|{},{}|{},{}".format(weight,
                                                                             box_y1, box_x1,
                                                                             box_y1, box_x2,
                                                                             box_y2, box_x2,
                                                                             box_y2, box_x1,
                                                                             box_y1, box_x1)

    # unique_id to identify the sample
    unique_id = maharashtra.iloc[idx]['unique_id']
    if (unique_id + '.' + img_format in already_downloaded) or (unique_id in labeled['unique_id'].values):
        continue # don't pull images that have already been pulled
    
    # get method of requests module returns response object
    r = requests.get(url + 
                     "center=" + center +
                     "&zoom=" + str(zoom) +
                     "&size=" + size +
                     "&maptype=satellite" +
                     "&format=" + img_format +
                     "&path=" + path +
                     "&key=" + api_key
                    )
    
    # write response to a file
    img_name = maharashtra.iloc[idx]['unique_id'] + '.' + img_format
    with open('../data/static_maps/unlabeled/{}'.format(img_name), 'wb') as f:
        f.write(r.content)

# %% [markdown]
# ## Data submission dates

# %%
date_to_idx = {}

for year in [2016, 2017, 2018, 2019]:
    d1 = date(year, 6, 1)     # start date
    d2 = date(year+1, 5, 31)  # end date

    delta = d2 - d1           # timedelta

    for i in range(delta.days + 1):
        date_to_idx[str(d1 + timedelta(i))] = i

# %%
months = ['Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May']
month_starts = [0, 30, 61, 92, 122, 153, 183, 214, 245, 273, 304, 334]
bins = np.linspace(0, 365, 366//2)

plt.hist(maharashtra[maharashtra['datetime'] < datetime(2019,6,1)]['datetime'].astype(str).str[:10].map(lambda x: date_to_idx[x]).values,
         bins=bins, color='C2', alpha=0.5)
plt.hist(maharashtra[maharashtra['datetime'] >= datetime(2019,6,1)]['datetime'].astype(str).str[:10].map(lambda x: date_to_idx[x]).values,
         bins=bins, color='C0', alpha=0.5)
plt.xticks(month_starts, months)
plt.legend(['2018-19', '2019-20'], loc='upper right', frameon=False)
plt.show()

# %% [markdown]
# ## Rename image files

# %%
img_dir = '../data/static_maps/'

for file_name in os.listdir(img_dir):
    number = file_name.split('_')[-1].split('.')[0]
    new_number = '0' + number
    new_file_name = file_name.split('_')[0] + '_' + new_number + '.jpg'
    os.rename(os.path.join(img_dir, file_name), 
              os.path.join(img_dir, new_file_name))

# %% [markdown]
# # Pull images from extended dataset that weren't included in old dataset

# %%
old_data = pd.read_csv('../data/maharashtra_infield_dataset.csv')
old_data.shape
# Out:
# (99459, 15)

# %%
new_not_in_old = new_data[~new_data['latlon'].isin(old_data['latlon'])]
new_not_in_old.shape
# Out:
# (158561, 12)

# %%
# remove submissions with accuracy = 0
new_not_in_old = new_not_in_old[new_not_in_old['accuracy'] > 0]
new_not_in_old.shape
# Out:
# (8580, 12)

# %%
unique = new_not_in_old.sort_values('accuracy')
unique = unique.drop_duplicates(['latlon'], keep='first')

# %%
# API key
api_key = 'AIzaSyCIzApnervVJRFp6gF16vJYBlL6zpuSbY8'

# base URL to add parameters to
url = "https://maps.googleapis.com/maps/api/staticmap?"

# directory to save images
img_dir = '../data/static_maps/unlabeled/'

# loop over indices of dataframe
for idx in range(1, unique.shape[0]):
    
    # center defines the center of the map, equidistant from all edges of the map
    lat = unique.iloc[idx]['latitude']
    lon = unique.iloc[idx]['longitude']
    center = "{},{}".format(lat, lon)

    # zoom defines the zoom level of the map (0=whole world, 22=building-level)
    zoom = 19

    # size defines the coverage area of the map
    # the max is 640x640. pretrained models take 224x224 as input
    pixels = 500
    size = "{}x{}".format(pixels, pixels)

    # image format can be png (8-bit is default), gif, or jpg
    img_format = "jpg"

    # draw a 10m-by-10m box to mark Sentinel-2 pixel
    weight = 4
    box_y1, box_x1, box_y2, box_x2 = latlon_to_box(lat, lon, dx=5, dy=5)
    path = "color:0xff0000ff|weight:{}|{},{}|{},{}|{},{}|{},{}|{},{}".format(weight,
                                                                             box_y1, box_x1,
                                                                             box_y1, box_x2,
                                                                             box_y2, box_x2,
                                                                             box_y2, box_x1,
                                                                             box_y1, box_x1)
    
    # get method of requests module returns response object
    r = requests.get(url + 
                     "center=" + center +
                     "&zoom=" + str(zoom) +
                     "&size=" + size +
                     "&maptype=satellite" +
                     "&format=" + img_format +
                     "&path=" + path +
                     "&key=" + api_key
                    )
    
    # write response to a file
    img_name = 'maharashtra_' + unique.iloc[idx]['pic_id'] + '.' + img_format
    with open('../data/static_maps/unlabeled/{}'.format(img_name), 'wb') as f:
        f.write(r.content)

# %% [markdown]
# # Pull images from 2018-Sep 2020 dataset

# %%
with open('../mount/raw_data/Maharashtra_2018-Sep2020.json') as f:
    j = json.load(f)
unique = pd.DataFrame(j)

unique.loc[:,'latitude'] = unique['location'].map(lambda x: x['coordinates'][1])
unique.loc[:,'longitude'] = unique['location'].map(lambda x: x['coordinates'][0])

# %%
# API key
api_key = 'AIzaSyCIzApnervVJRFp6gF16vJYBlL6zpuSbY8'

# base URL to add parameters to
url = "https://maps.googleapis.com/maps/api/staticmap?"

# directory to save images
img_dir = '../data/static_maps/unlabeled/'

# loop over indices of dataframe
for idx in range(unique.shape[0]):
    
    # center defines the center of the map, equidistant from all edges of the map
    lat = unique.iloc[idx]['latitude']
    lon = unique.iloc[idx]['longitude']
    center = "{},{}".format(lat, lon)

    # zoom defines the zoom level of the map (0=whole world, 22=building-level)
    zoom = 19

    # size defines the coverage area of the map
    # the max is 640x640. pretrained models take 224x224 as input
    pixels = 500
    size = "{}x{}".format(pixels, pixels)

    # image format can be png (8-bit is default), gif, or jpg
    img_format = "jpg"

    # draw a 10m-by-10m box to mark Sentinel-2 pixel
    weight = 4
    box_y1, box_x1, box_y2, box_x2 = latlon_to_box(lat, lon, dx=5, dy=5)
    path = "color:0xff0000ff|weight:{}|{},{}|{},{}|{},{}|{},{}|{},{}".format(weight,
                                                                             box_y1, box_x1,
                                                                             box_y1, box_x2,
                                                                             box_y2, box_x2,
                                                                             box_y2, box_x1,
                                                                             box_y1, box_x1)
    
    # get method of requests module returns response object
    r = requests.get(url + 
                     "center=" + center +
                     "&zoom=" + str(zoom) +
                     "&size=" + size +
                     "&maptype=satellite" +
                     "&format=" + img_format +
                     "&path=" + path +
                     "&key=" + api_key
                    )
    
    # write response to a file
    img_name = 'maharashtra_' + unique.iloc[idx]['pic_id'] + '.' + img_format
    with open('../data/static_maps/unlabeled/{}'.format(img_name), 'wb') as f:
        f.write(r.content)

# %% [markdown]
# # Pull images even if GPS accuracy not good

# %%
# unique = pd.read_csv('../mount/raw_data/Maharashtra_combined_20201015.csv')
# unlabeled_dir = '../data/static_maps/unlabeled/unlabeled'

# # failed image to compare
# # failed_img_name = os.path.join(unlabeled_dir, 'maharashtra_a7968833-929c-4ee0-9baa-ef4ee8b7dbe2.jpg')
# # failed_img = imageio.imread(failed_img_name)

# already_pulled = os.listdir(unlabeled_dir)
# for fold in ['train', 'val', 'test']:
#     count = 0
#     for label in ['in_field', 'more_than_half', 'less_than_half', 'not_in_field']:
#         already_pulled = already_pulled + os.listdir(os.path.join('../data/static_maps',
#                                                                   fold, label))
#         count += len(os.listdir(os.path.join('../data/static_maps', fold, label)))
        
#     print(count)    
# already_pulled = [x.split('_')[-1].split('.')[0] for x in already_pulled]

# unique = unique[~unique['pic_id'].isin(already_pulled)]
# Out:
# 1000
# 100
# 100

# %%
# unique = pd.read_csv('../data/maharashtra_20201208_static-map-not-downloaded.csv')

# %%
unique = pd.read_csv('../data/maharashtra_jan2018-dec2020_no-duplicates.csv')
unlabeled_dir = '../data/static_maps/unlabeled/unlabeled'

already_pulled = os.listdir(unlabeled_dir)
for fold in ['train', 'val', 'test']:
    count = 0
    for label in ['in_field', 'more_than_half', 'less_than_half', 'not_in_field']:
        already_pulled = already_pulled + os.listdir(os.path.join('../data/static_maps',
                                                                  fold, label))
        count += len(os.listdir(os.path.join('../data/static_maps', fold, label)))
        
    print(count)    
already_pulled = [x.split('_')[-1].split('.')[0] for x in already_pulled]

unique = unique[~unique['pic_id'].isin(already_pulled)]
# Out:
# 1000
# 100
# 100

# %%
unique.shape
# Out:
# (50946, 13)

# %%
# directory to save images
img_dir = '../data/static_maps/unlabeled/unlabeled'

# base URL to add parameters to
url = "https://maps.googleapis.com/maps/api/staticmap?"

# do not exceed 100k downloads in one month
count = 0
print_every = 1000

# loop over indices of dataframe
for idx in range(unique.shape[0]):
    
    # center defines the center of the map, equidistant from all edges of the map
    lat = unique.iloc[idx]['latitude']
    lon = unique.iloc[idx]['longitude']
    center = "{},{}".format(lat, lon)

    # zoom defines the zoom level of the map (0=whole world, 22=building-level)
    zoom = 19

    # size defines the coverage area of the map
    # the max is 640x640. pretrained models take 224x224 as input
    pixels = 500
    size = "{}x{}".format(pixels, pixels)

    # image format can be png (8-bit is default), gif, or jpg
    img_format = "jpg"

    # draw a 10m-by-10m box to mark Sentinel-2 pixel
    weight = 4
    box_y1, box_x1, box_y2, box_x2 = latlon_to_box(lat, lon, dx=5, dy=5)
    path = "color:0xff0000ff|weight:{}|{},{}|{},{}|{},{}|{},{}|{},{}".format(weight,
                                                                             box_y1, box_x1,
                                                                             box_y1, box_x2,
                                                                             box_y2, box_x2,
                                                                             box_y2, box_x1,
                                                                             box_y1, box_x1)
    
    # get method of requests module returns response object
    input_url = url + \
                "center=" + urlparse.quote(center) + \
                "&zoom=" + str(zoom) + \
                "&size=" + size + \
                "&maptype=satellite" + \
                "&format=" + img_format + \
                "&path=" + urlparse.quote(path) + \
                "&key=" + api_key
    signed_url = sign_url(input_url, secret)
    r = requests.get(signed_url)
    
    # write response to a file
    img_name = 'maharashtra_' + unique.iloc[idx]['pic_id'] + '.' + img_format
    # print(img_name)
    with open(os.path.join(img_dir, '{}'.format(img_name)), 'wb') as f:
        f.write(r.content)
        
    count += 1
    if count % print_every == 0:
        print(count)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000

# %%
im = imageio.imread('../data/static_maps/unlabeled/unlabeled/maharashtra_0de61038-afa9-4cc5-83aa-d48df0ae8637.jpg')
plt.imshow(im)
plt.show()

# %%
im = imageio.imread('../data/static_maps/unlabeled/unlabeled/maharashtra_aef4406c-af41-48a2-ab2b-f9dbe298d1fe.jpg')
plt.imshow(im)
plt.show()

# %%
# some images failed to download for some reason
failed_ids = ['85171655-eb59-4b9d-bbe4-beb3eba60fef']
unique = unique[unique['pic_id'].isin(failed_ids)].reset_index(drop=True)

# %%
# directory to save images
img_dir = '../data/static_maps/unlabeled/unlabeled'

# base URL to add parameters to
url = "https://maps.googleapis.com/maps/api/staticmap?"

# do not exceed 100k downloads in one month
count = 0
print_every = 1000

# loop over indices of dataframe
for idx in range(len(failed_ids)): #(unique.shape[0]):
    
    # center defines the center of the map, equidistant from all edges of the map
    lat = unique.iloc[idx]['latitude']
    lon = unique.iloc[idx]['longitude']
    center = "{},{}".format(lat, lon)

    # zoom defines the zoom level of the map (0=whole world, 22=building-level)
    zoom = 19

    # size defines the coverage area of the map
    # the max is 640x640. pretrained models take 224x224 as input
    pixels = 500
    size = "{}x{}".format(pixels, pixels)

    # image format can be png (8-bit is default), gif, or jpg
    img_format = "jpg"

    # draw a 10m-by-10m box to mark Sentinel-2 pixel
    weight = 4
    box_y1, box_x1, box_y2, box_x2 = latlon_to_box(lat, lon, dx=5, dy=5)
    path = "color:0xff0000ff|weight:{}|{},{}|{},{}|{},{}|{},{}|{},{}".format(weight,
                                                                             box_y1, box_x1,
                                                                             box_y1, box_x2,
                                                                             box_y2, box_x2,
                                                                             box_y2, box_x1,
                                                                             box_y1, box_x1)
    
    # get method of requests module returns response object
    input_url = url + \
                "center=" + urlparse.quote(center) + \
                "&zoom=" + str(zoom) + \
                "&size=" + size + \
                "&maptype=satellite" + \
                "&format=" + img_format + \
                "&path=" + urlparse.quote(path) + \
                "&key=" + api_key
    signed_url = sign_url(input_url, secret)
    r = requests.get(signed_url)
    
    # write response to a file
    img_name = 'maharashtra_' + unique.iloc[idx]['pic_id'] + '.' + img_format
    # print(img_name)
    with open(os.path.join(img_dir, '{}'.format(img_name)), 'wb') as f:
        f.write(r.content)
        
    count += 1
    if count % print_every == 0:
        print(count)
