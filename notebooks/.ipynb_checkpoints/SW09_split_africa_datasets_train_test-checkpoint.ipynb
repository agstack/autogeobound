# %%
import numpy as np
import pandas as pd
import os
import copy
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
# %matplotlib inline

from osgeo import gdal, ogr, osr
from shapely.geometry import Polygon, box
import imageio

# %% [markdown]
# # Split Africa datasets into train, val, test

# %% [markdown]
# ## Senegal

# %%
senegal_tiles = pd.read_csv('../data/planet/senegal/bbox_tiles_overlap.csv')
senegal_tiles['image_id'] = senegal_tiles['image_id'].astype(str).str.zfill(5)

# %%
senegal_tiles.head()
# Out:
#   image_id    min_lon    min_lat    max_lon    max_lat
# 0    00060 -16.336502  14.252279 -16.324936  14.263559
# 1    00141 -16.325178  14.252342 -16.313613  14.263622
# 2    00142 -16.325243  14.263386 -16.313677  14.274666
# 3    00221 -16.313791  14.241360 -16.302227  14.252640
# 4    00222 -16.313855  14.252404 -16.302290  14.263684

# %%
df = senegal_tiles.copy()

tile_ids = df['image_id'].values
sampled = []
folds = []
tiles_to_check = set()

for i, row in df.iterrows():
    tile_id = row['image_id']
    
    if tile_id not in sampled:
        print("Sampling a new tile, tile", tile_id)
        
        # if tile hasn't been sampled already,
        # assign it to a fold
        fold = np.random.choice(['train', 'val', 'test'], p=[0.6, 0.2, 0.2])
        sampled.append(tile_id)
        folds.append(fold)
        
        min_lon, min_lat = row['min_lon'], row['min_lat']
        max_lon, max_lat = row['max_lon'], row['max_lat']
        tiles_to_check.add((tile_id, min_lon, min_lat, max_lon, max_lat))
        
        while tiles_to_check != set():
            tile_id, min_lon, min_lat, max_lon, max_lat = tiles_to_check.pop()
            tile_poly = box(min_lon, min_lat, max_lon, max_lat)
            possibly_overlapping_tiles = df[(df['max_lon'] >= min_lon) &
                                            (df['min_lon'] <= max_lon) &
                                            (df['max_lat'] >= min_lat) & 
                                            (df['min_lat'] <= max_lat)].reset_index(drop=True)

            for j, row2 in possibly_overlapping_tiles.iterrows():
                tile_id2 = row2['image_id']
                
                if tile_id2 not in sampled:
                    print("    Tile {} is connected".format(tile_id2))
                    min_lon2, min_lat2 = row2['min_lon'], row2['min_lat']
                    max_lon2, max_lat2 = row2['max_lon'], row2['max_lat']
                    tile_poly2 = box(min_lon2, min_lat2, max_lon2, max_lat2)

                    if tile_poly.intersects(tile_poly2):
                        # assign all touching tiles to the same fold
                        sampled.append(tile_id2)
                        folds.append(fold)
                        tiles_to_check.add((tile_id2, min_lon2, min_lat2, max_lon2, max_lat2))
# Out:
# Sampling a new tile, tile 00060
#     Tile 00141 is connected
#     Tile 00142 is connected
#     Tile 00222 is connected
#     Tile 00223 is connected
#     Tile 00224 is connected
#     Tile 00221 is connected
#     Tile 00302 is connected
#     Tile 00303 is connected
#     Tile 00304 is connected
#     Tile 00383 is connected
#     Tile 00384 is connected
#     Tile 00225 is connected
#     Tile 00385 is connected
#     Tile 00386 is connected
# Sampling a new tile, tile 00297
#     Tile 00298 is connected
#     Tile 00378 is connected
#     Tile 00379 is connected
#     Tile 00380 is connected
#     Tile 00461 is connected
#     Tile 00381 is connected
#     Tile 00462 is connected
#     Tile 00300 is connected
# Sampling a new tile, tile 01009
#     Tile 01010 is connected
#     Tile 01090 is connected
#     Tile 01091 is connected
#     Tile 01011 is connected
#     Tile 01092 is connected
#     Tile 01173 is connected
#     Tile 01093 is connected
#     Tile 01174 is connected
# Sampling a new tile, tile 01223
#     Tile 01303 is connected
#     Tile 01304 is connected
#     Tile 01305 is connected
#     Tile 01384 is connected
#     Tile 01385 is connected
#     Tile 01386 is connected
# Sampling a new tile, tile 01249
#     Tile 01250 is connected
#     Tile 01330 is connected
#     Tile 01331 is connected
#     Tile 01251 is connected
#     Tile 01252 is connected
# Sampling a new tile, tile 01313
#     Tile 01314 is connected
#     Tile 01394 is connected
#     Tile 01395 is connected
# Sampling a new tile, tile 01339
#     Tile 01340 is connected
#     Tile 01420 is connected
#     Tile 01421 is connected
#     Tile 01501 is connected
#     Tile 01502 is connected
#     Tile 01583 is connected
# Sampling a new tile, tile 01487
#     Tile 01488 is connected
#     Tile 01567 is connected
#     Tile 01568 is connected
#     Tile 01569 is connected
#     Tile 01650 is connected
#     Tile 01570 is connected
# Sampling a new tile, tile 01522
#     Tile 01603 is connected
#     Tile 01604 is connected
#     Tile 01683 is connected
#     Tile 01684 is connected
#     Tile 01685 is connected
#     Tile 01524 is connected
#     Tile 01764 is connected
#     Tile 01765 is connected
#     Tile 01766 is connected
#     Tile 01844 is connected
#     Tile 01762 is connected
#     Tile 01843 is connected
#     Tile 01924 is connected
#     Tile 01925 is connected
#     Tile 01842 is connected
#     Tile 02007 is connected
#     Tile 02087 is connected
#     Tile 02088 is connected
#     Tile 02089 is connected
#     Tile 01923 is connected
#     Tile 02168 is connected
#     Tile 02169 is connected
#     Tile 02170 is connected
#     Tile 02250 is connected
#     Tile 02248 is connected
# Sampling a new tile, tile 01596
#     Tile 01597 is connected
#     Tile 01677 is connected
#     Tile 01678 is connected
#     Tile 01758 is connected
#     Tile 01759 is connected
#     Tile 01839 is connected
#     Tile 01840 is connected
# Sampling a new tile, tile 01630
#     Tile 01710 is connected
#     Tile 01711 is connected
#     Tile 01791 is connected
#     Tile 01792 is connected
#     Tile 01790 is connected
#     Tile 01871 is connected
#     Tile 01872 is connected
#     Tile 01873 is connected
#     Tile 01952 is connected
#     Tile 02032 is connected
#     Tile 02033 is connected
#     Tile 02034 is connected
# Sampling a new tile, tile 01891
#     Tile 01892 is connected
#     Tile 01972 is connected
#     Tile 01973 is connected
# Sampling a new tile, tile 01896
#     Tile 01897 is connected
#     Tile 01977 is connected
#     Tile 01978 is connected
#     Tile 01979 is connected
# Sampling a new tile, tile 02158
#     Tile 02159 is connected
#     Tile 02240 is connected
#     Tile 02321 is connected
# Sampling a new tile, tile 02410
#     Tile 02411 is connected
#     Tile 02490 is connected
#     Tile 02491 is connected
#     Tile 02493 is connected
#     Tile 02571 is connected
#     Tile 02572 is connected
#     Tile 02652 is connected
# Sampling a new tile, tile 02416
#     Tile 02417 is connected
#     Tile 02497 is connected
#     Tile 02498 is connected
#     Tile 02577 is connected
#     Tile 02578 is connected
#     Tile 02579 is connected
#     Tile 02660 is connected
#     Tile 02499 is connected
#     Tile 02580 is connected
#     Tile 02661 is connected
#     Tile 02418 is connected
#     Tile 02581 is connected
#     Tile 02500 is connected
#     Tile 02419 is connected
# Sampling a new tile, tile 02696
#     Tile 02697 is connected
#     Tile 02777 is connected
#     Tile 02778 is connected
# Sampling a new tile, tile 02726
#     Tile 02727 is connected
#     Tile 02807 is connected
#     Tile 02808 is connected
#     Tile 02728 is connected
#     Tile 02809 is connected
# Sampling a new tile, tile 03082
#     Tile 03083 is connected
#     Tile 03163 is connected
#     Tile 03164 is connected
#     Tile 03244 is connected
#     Tile 03245 is connected
#     Tile 03246 is connected
# Sampling a new tile, tile 03414
#     Tile 03415 is connected
#     Tile 03495 is connected
#     Tile 03496 is connected
#     Tile 03576 is connected
#     Tile 03577 is connected
#     Tile 03575 is connected
# Sampling a new tile, tile 03460
#     Tile 03461 is connected
#     Tile 03541 is connected
#     Tile 03542 is connected
#     Tile 03462 is connected
#     Tile 03543 is connected
# Sampling a new tile, tile 03570
#     Tile 03651 is connected
#     Tile 03652 is connected
#     Tile 03732 is connected
#     Tile 03733 is connected
# Sampling a new tile, tile 03599
#     Tile 03679 is connected
#     Tile 03680 is connected
#     Tile 03760 is connected
#     Tile 03761 is connected
#     Tile 03841 is connected
#     Tile 03842 is connected
# Sampling a new tile, tile 03664
#     Tile 03665 is connected
#     Tile 03745 is connected
#     Tile 03746 is connected
#     Tile 03666 is connected
#     Tile 03747 is connected
#     Tile 03827 is connected
#     Tile 03828 is connected
#     Tile 03909 is connected
#     Tile 03829 is connected
#     Tile 03989 is connected
#     Tile 04069 is connected
#     Tile 04070 is connected
#     Tile 03667 is connected
#     Tile 04150 is connected
#     Tile 04151 is connected
#     Tile 04231 is connected
# Sampling a new tile, tile 03683
#     Tile 03684 is connected
#     Tile 03764 is connected
#     Tile 03765 is connected
#     Tile 03685 is connected
# Sampling a new tile, tile 03980
#     Tile 04060 is connected
#     Tile 04061 is connected
#     Tile 04141 is connected
#     Tile 04142 is connected
#     Tile 04221 is connected
#     Tile 04222 is connected
#     Tile 04302 is connected
# Sampling a new tile, tile 04270
#     Tile 04271 is connected
#     Tile 04352 is connected
#     Tile 04432 is connected
#     Tile 04433 is connected
#     Tile 04434 is connected
#     Tile 04514 is connected
#     Tile 04515 is connected
#     Tile 04516 is connected
#     Tile 04595 is connected
#     Tile 04596 is connected
# Sampling a new tile, tile 04333
#     Tile 04334 is connected
#     Tile 04413 is connected
#     Tile 04414 is connected
#     Tile 04335 is connected
#     Tile 04494 is connected
#     Tile 04495 is connected
#     Tile 04496 is connected
# Sampling a new tile, tile 04388
#     Tile 04389 is connected
#     Tile 04469 is connected
#     Tile 04470 is connected
#     Tile 04390 is connected
# Sampling a new tile, tile 04460
#     Tile 04461 is connected
#     Tile 04542 is connected
#     Tile 04462 is connected
#     Tile 04544 is connected
#     Tile 04545 is connected
#     Tile 04465 is connected
#     Tile 04546 is connected
#     Tile 04627 is connected
#     Tile 04466 is connected
#     Tile 04628 is connected
# Sampling a new tile, tile 04479
#     Tile 04480 is connected
#     Tile 04560 is connected
#     Tile 04561 is connected
#     Tile 04481 is connected
#     Tile 04562 is connected
#     Tile 04641 is connected
#     Tile 04642 is connected
# Sampling a new tile, tile 04492
# Sampling a new tile, tile 04529
#     Tile 04530 is connected
#     Tile 04609 is connected
#     Tile 04610 is connected
#     Tile 04611 is connected
#     Tile 04690 is connected
#     Tile 04691 is connected
#     Tile 04692 is connected
#     Tile 04770 is connected
#     Tile 04612 is connected
#     Tile 04851 is connected
# Sampling a new tile, tile 04588
#     Tile 04668 is connected
#     Tile 04669 is connected
#     Tile 04670 is connected
#     Tile 04749 is connected
#     Tile 04750 is connected
#     Tile 04830 is connected
#     Tile 04831 is connected
#     Tile 04751 is connected
#     Tile 04752 is connected
#     Tile 04832 is connected
#     Tile 04833 is connected
#     Tile 04913 is connected
#     Tile 04914 is connected
# Sampling a new tile, tile 04779
#     Tile 04860 is connected
#     Tile 04861 is connected
#     Tile 04941 is connected
# Sampling a new tile, tile 05137
#     Tile 05217 is connected
#     Tile 05218 is connected
#     Tile 05298 is connected
#     Tile 05299 is connected
#     Tile 05379 is connected
#     Tile 05380 is connected
# Sampling a new tile, tile 05144
#     Tile 05224 is connected
#     Tile 05225 is connected
#     Tile 05226 is connected
#     Tile 05223 is connected
#     Tile 05304 is connected
#     Tile 05305 is connected
#     Tile 05306 is connected
#     Tile 05387 is connected
#     Tile 05227 is connected
#     Tile 05307 is connected
#     Tile 05308 is connected
#     Tile 05388 is connected
#     Tile 05228 is connected
#     Tile 05309 is connected
# Sampling a new tile, tile 05189
#     Tile 05190 is connected
#     Tile 05271 is connected
#     Tile 05191 is connected
# Sampling a new tile, tile 05284
#     Tile 05285 is connected
#     Tile 05365 is connected
#     Tile 05366 is connected
#     Tile 05446 is connected
# Sampling a new tile, tile 06778
#     Tile 06779 is connected
#     Tile 06858 is connected
#     Tile 06859 is connected
#     Tile 06860 is connected
#     Tile 06939 is connected
#     Tile 06940 is connected
#     Tile 06941 is connected
#     Tile 06780 is connected
#     Tile 06861 is connected
#     Tile 06862 is connected
# Sampling a new tile, tile 06932
#     Tile 06933 is connected
#     Tile 07013 is connected
#     Tile 07014 is connected
#     Tile 06934 is connected
#     Tile 07015 is connected
#     Tile 07094 is connected
#     Tile 07095 is connected
#     Tile 07096 is connected
#     Tile 07016 is connected
# Sampling a new tile, tile 06996
#     Tile 07076 is connected
#     Tile 07077 is connected
#     Tile 07078 is connected
#     Tile 07079 is connected
#     Tile 07158 is connected
#     Tile 07159 is connected
#     Tile 07160 is connected
#     Tile 07240 is connected
#     Tile 07241 is connected
#     Tile 07242 is connected
#     Tile 07323 is connected
#     Tile 07243 is connected
#     Tile 07163 is connected
#     Tile 07244 is connected
#     Tile 07325 is connected
#     Tile 07164 is connected
#     Tile 07245 is connected
#     Tile 07165 is connected
#     Tile 07246 is connected
# Sampling a new tile, tile 07091
#     Tile 07092 is connected
#     Tile 07171 is connected
#     Tile 07172 is connected
#     Tile 07173 is connected
#     Tile 07252 is connected
#     Tile 07253 is connected
#     Tile 07254 is connected
#     Tile 07170 is connected
#     Tile 07251 is connected
# Sampling a new tile, tile 07151
#     Tile 07152 is connected
#     Tile 07232 is connected
#     Tile 07233 is connected
#     Tile 07234 is connected
#     Tile 07314 is connected
#     Tile 07315 is connected
#     Tile 07313 is connected
#     Tile 07393 is connected
#     Tile 07394 is connected
#     Tile 07395 is connected
#     Tile 07474 is connected
#     Tile 07475 is connected
#     Tile 07392 is connected
#     Tile 07473 is connected
#     Tile 07555 is connected
#     Tile 07556 is connected
#     Tile 07557 is connected
#     Tile 07554 is connected
# Sampling a new tile, tile 08796
#     Tile 08797 is connected
#     Tile 08876 is connected
#     Tile 08877 is connected
#     Tile 08878 is connected
#     Tile 08957 is connected
#     Tile 08958 is connected
#     Tile 08959 is connected
# Sampling a new tile, tile 09667
#     Tile 09748 is connected
#     Tile 09749 is connected
#     Tile 09829 is connected
#     Tile 09830 is connected
#     Tile 09750 is connected
#     Tile 09831 is connected
# Sampling a new tile, tile 11253
#     Tile 11335 is connected
#     Tile 11417 is connected
#     Tile 11418 is connected
#     Tile 11499 is connected
#     Tile 11500 is connected
#     Tile 11581 is connected
#     Tile 11582 is connected
#     Tile 11501 is connected
#     Tile 11583 is connected
#     Tile 11337 is connected
#     Tile 11255 is connected
#     Tile 11338 is connected
# Sampling a new tile, tile 11286
#     Tile 11287 is connected
#     Tile 11368 is connected
#     Tile 11369 is connected
#     Tile 11370 is connected
#     Tile 11450 is connected
#     Tile 11451 is connected
#     Tile 11452 is connected
#     Tile 11533 is connected
#     Tile 11532 is connected
#     Tile 11449 is connected
#     Tile 11289 is connected
#     Tile 11448 is connected
# Sampling a new tile, tile 11492
#     Tile 11574 is connected
# Sampling a new tile, tile 11576
#     Tile 11577 is connected
#     Tile 11658 is connected
#     Tile 11659 is connected
#     Tile 11740 is connected
#     Tile 11741 is connected
#     Tile 11742 is connected
#     Tile 11823 is connected
#     Tile 11824 is connected
#     Tile 11825 is connected
#     Tile 11905 is connected
#     Tile 11906 is connected
#     Tile 11907 is connected
#     Tile 11908 is connected
#     Tile 11990 is connected
#     Tile 11909 is connected
#     Tile 11991 is connected
#     Tile 11904 is connected
#     Tile 11827 is connected
# Sampling a new tile, tile 11651
#     Tile 11733 is connected
#     Tile 11734 is connected
#     Tile 11815 is connected
#     Tile 11817 is connected
#     Tile 11898 is connected
#     Tile 11899 is connected
#     Tile 11818 is connected
#     Tile 11900 is connected
#     Tile 11982 is connected
#     Tile 11901 is connected
#     Tile 11819 is connected
# Sampling a new tile, tile 11966
#     Tile 12047 is connected
#     Tile 12048 is connected
#     Tile 12049 is connected
#     Tile 12130 is connected
# Sampling a new tile, tile 12066
#     Tile 12067 is connected
#     Tile 12147 is connected
#     Tile 12148 is connected
#     Tile 12149 is connected
#     Tile 12230 is connected
#     Tile 12068 is connected
#     Tile 12150 is connected
#     Tile 12231 is connected
#     Tile 12232 is connected
#     Tile 12312 is connected
#     Tile 12313 is connected
#     Tile 12314 is connected
#     Tile 12394 is connected
#     Tile 12311 is connected
#     Tile 12393 is connected
#     Tile 12475 is connected
#     Tile 12476 is connected
#     Tile 12310 is connected
#     Tile 12474 is connected
#     Tile 12557 is connected
# Sampling a new tile, tile 12398
#     Tile 12399 is connected
#     Tile 12479 is connected
#     Tile 12480 is connected
#     Tile 12562 is connected
#     Tile 12563 is connected
#     Tile 12644 is connected
#     Tile 12726 is connected
#     Tile 12727 is connected
# Sampling a new tile, tile 12566
#     Tile 12567 is connected
#     Tile 12647 is connected
#     Tile 12648 is connected
#     Tile 12649 is connected
#     Tile 12730 is connected
#     Tile 12731 is connected
#     Tile 12729 is connected
# Sampling a new tile, tile 12635
#     Tile 12636 is connected
#     Tile 12717 is connected
#     Tile 12718 is connected
#     Tile 12799 is connected
#     Tile 12800 is connected
#     Tile 12637 is connected
#     Tile 12719 is connected
# Sampling a new tile, tile 12681
#     Tile 12682 is connected
#     Tile 12763 is connected
#     Tile 12764 is connected
#     Tile 12683 is connected
#     Tile 12765 is connected
#     Tile 12845 is connected
#     Tile 12846 is connected
#     Tile 12847 is connected
#     Tile 12927 is connected
#     Tile 12928 is connected
#     Tile 12929 is connected
#     Tile 12766 is connected
#     Tile 12848 is connected
#     Tile 12767 is connected
# Sampling a new tile, tile 12886
#     Tile 12968 is connected
#     Tile 13050 is connected
#     Tile 13133 is connected
#     Tile 13215 is connected
#     Tile 13216 is connected
#     Tile 13298 is connected
#     Tile 13135 is connected
#     Tile 13217 is connected
#     Tile 13299 is connected
#     Tile 13053 is connected
# Sampling a new tile, tile 13064
#     Tile 13146 is connected
#     Tile 13147 is connected
#     Tile 13148 is connected
#     Tile 13228 is connected
#     Tile 13229 is connected
#     Tile 13311 is connected
#     Tile 13227 is connected
#     Tile 13392 is connected
#     Tile 13393 is connected
#     Tile 13474 is connected
# Sampling a new tile, tile 13282
#     Tile 13364 is connected
#     Tile 13365 is connected
#     Tile 13284 is connected
#     Tile 13366 is connected
#     Tile 13446 is connected
#     Tile 13447 is connected
#     Tile 13448 is connected
#     Tile 13285 is connected
#     Tile 13449 is connected
#     Tile 13529 is connected
#     Tile 13530 is connected
#     Tile 13611 is connected
#     Tile 13612 is connected
#     Tile 13613 is connected
#     Tile 13445 is connected
#     Tile 13528 is connected
#     Tile 13694 is connected
#     Tile 13693 is connected
#     Tile 13775 is connected
#     Tile 13450 is connected
#     Tile 13692 is connected
#     Tile 13774 is connected
#     Tile 13856 is connected
#     Tile 13857 is connected
#     Tile 13773 is connected
#     Tile 13855 is connected
#     Tile 13938 is connected
#     Tile 13772 is connected
#     Tile 13854 is connected
#     Tile 13691 is connected
#     Tile 13940 is connected
#     Tile 13690 is connected
#     Tile 14022 is connected
# Sampling a new tile, tile 13678
#     Tile 13760 is connected
#     Tile 13761 is connected
#     Tile 13843 is connected
#     Tile 13844 is connected
#     Tile 13845 is connected
#     Tile 13927 is connected
# Sampling a new tile, tile 13860
# Sampling a new tile, tile 14207
#     Tile 14288 is connected
#     Tile 14289 is connected
#     Tile 14372 is connected
#     Tile 14373 is connected
#     Tile 14454 is connected
#     Tile 14455 is connected
#     Tile 14537 is connected
#     Tile 14535 is connected
#     Tile 14534 is connected

# %%
split_df = pd.DataFrame({
    'image_id': sampled,
    'fold': folds
})

# %%
split_df.groupby('fold').size() / split_df.shape[0]
# Out:
# fold
# test     0.166392
# train    0.634267
# val      0.199341
# dtype: float64

# %%
merged_split_df = senegal_tiles.merge(split_df, on='image_id', how='left')

# %%
merged_split_df.to_csv('../data/splits/senegal_planetImagery_splits_tiles_overlap.csv',
                       index=False)

# %%
fig, ax = plt.subplots(1, figsize=(20,10), sharex=True, sharey=True)

for i, row in merged_split_df.iterrows():
    if row['fold'] == 'train':
        c = 'C0'
    elif row['fold'] == 'val':
        c = 'C2'
    elif row['fold'] == 'test':
        c = 'C1'
    ax.vlines(row['min_lon'], row['min_lat'], row['max_lat'], color=c)
    ax.vlines(row['max_lon'], row['min_lat'], row['max_lat'], color=c)
    ax.hlines(row['min_lat'], row['min_lon'], row['max_lon'], color=c)
    ax.hlines(row['max_lat'], row['min_lon'], row['max_lon'], color=c)
plt.show()
