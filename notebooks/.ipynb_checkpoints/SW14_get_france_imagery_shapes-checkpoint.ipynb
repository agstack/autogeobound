# %%
# Author: Stefania Di Tommaso (sditom@stanford.edu)
# Guide: see HowToDownloadMosaics.docx

import requests
import os
import numpy as np
import pandas as pd
from osgeo import gdal # to crop tile
import shutil
import imageio

# %%
################################################################################
##  Objective: Download MOSAICS RGB given a AOI defined in the bbox variable  ##
################################################################################


####----------------------------Settings------------------------------------####
# Set API key
os.environ['PL_API_KEY'] = ''
my_auth_key = os.getenv('PL_API_KEY')

# Set AOI file
# FRANCE
base_dir = os.path.join('..', 'data', 'planet', 'france', 'sherrie10k')
bbox_df = pd.read_csv(os.path.join(base_dir, 'bbox10k_2500px.csv'), dtype=str)
bbox_df['image_id'] = bbox_df['image_id'].str.replace('_', '')
geojsonFolder = os.path.join(base_dir, 'input_locations', 'geojson_2500px')

# Set years and months of interest
year = '_2019_'
months = ['_10_']

# Set output Folder
outFolder = os.path.join(base_dir, 'temp_monthly_mosaics')
outFolder_renamed = os.path.join(base_dir, 'monthly_mosaics_renamed') # FINAL FOLDER IF RENAMING FILES

# Set folders used in clipping/merging client side
outFolder_clipped = os.path.join(base_dir, 'temp_monthly_mosaics_renamed_clipped') # TEMPORARY
outFolder_final = os.path.join(base_dir, 'monthly_mosaics_renamed_clipped_merged') # FINAL FOLDER IF CLIP-MERGE FILES
################################################################################

# %%
##########------- List All mosaics available with your account------############
headers = {
    'Authorization': 'api-key' + ' ' + my_auth_key,
}
response = requests.get('https://api.planet.com/basemaps/v1/mosaics', headers=headers)
print(response.status_code)

if response.status_code == 200: # ok, proceed
    # print(response.json())
    mosaic_names = []
    for thisMosaic in response.json()['mosaics']:
        mosaic_names.append(thisMosaic['name'])
    # print('All Available mosaics: \n {}'.format(mosaic_names))
else:
    error_msg = 'Error code {}: {}'.format(response.status_code, response.text)
    print(error_msg)
    os.sys.exit(1)
################################################################################
# Out:
# 200

# %%
########---------- Subset Mosaics to Month-year of interest ----------##########

my_mosaics_year = [m for m in mosaic_names if year in m]
# subset to  January, April, July, October
my_mosaics = []
for mos in my_mosaics_year:
    for mon in months:
        if mon in mos:
            my_mosaics.append(mos)
# print('mosaics: 2018 Jan,Apr,Jul,Oct:  {} \n'.format(my_mosaics))
################################################################################

# %%
############## ---------- Retrive List of AOI ----------########################
# print(bbox_df.head(3))
bbox_df["bbox"] = bbox_df["min_lon"] + ',' +\
                  bbox_df["min_lat"] + ',' +\
                  bbox_df["max_lon"] + ',' +\
                  bbox_df["max_lat"]

bbox_list = bbox_df["bbox"].tolist()
bbox_names_list = bbox_df["image_id"].tolist()
# print('AOIs: {} \n'.format(len(bbox_list)))
################################################################################

# %%
def tileSearch(mosaic, bbox):
    # Do Tile Search and print on screen
    search_cmd = 'planet mosaics search' + ' ' + mosaic + ' ' + '--bbox' + ' ' + bbox + ' ' + '| jq ."items[].id"'
    output = os.popen(search_cmd).read()
    tile_list = output.split('\n')[:-1]
    print('        {0}: tiles to download:{1}'.format(mosaic,tile_list))


def tileDownload(mosaic, bbox, outdir):
    # save each mosaic-tiles in a separate folder named as year_month
    year_month = '_'.join(mosaic.split('_')[2:4])
    outputFolder = os.path.join(outFolder, outdir, year_month)
    if not os.path.exists(outputFolder):
        # print('Create dir {}..'.format(outputFolder))
        os.makedirs(outputFolder)
    download_cmd = 'planet mosaics download' + ' ' + mosaic + ' ' + '--bbox' + ' ' + bbox + ' ' + '--dest'+ ' ' + outputFolder
    print(download_cmd)
    output = os.popen(download_cmd).read()


def rename_files(outTempFolder, outFinalFolder):
    ######## Script for renaming all the files and save them in a unique folder #########
    ## rename: Aoi_year_month_tileId.tif
    for direc, subdir, listfilename in os.walk(outTempFolder):
        for filename in listfilename:
            dir_yearmonth = os.path.split(direc)[1] #'2018_10'
            dir_aoi = os.path.split(os.path.split(direc)[0])[1] #'7068978'
            new_filename = '_'.join([dir_aoi, dir_yearmonth, filename])
            # print(new_filename)
            src = os.path.join(direc, filename)
            if not os.path.exists(outFinalFolder):
                os.makedirs(outFinalFolder)
            dst = os.path.join(outFinalFolder, new_filename)
            os.rename(src, dst)


def delete_empty_folders(outTempFolder):
    ## Starting from outTempFolder deletes all empty folders
    # Note: after the renaming the files have been moved.
    # so folders should be all empty. if one is not, means something went wrong with renaming.
    # so checking if they are empty before deletinf is a sanity check
    # that all data have been saved in the final folder
    for root, dirs, files in os.walk(outTempFolder, topdown=False):
        for name in dirs:
            thisDir = os.path.join(root, name)
            if not os.listdir(thisDir):
#                 print(thisDir + ' is empty. It will be removed')
                os.rmdir(thisDir)
    # if all folders are empty -> remove Parent folder
    if not os.listdir(outTempFolder):
#         print(outTempFolder + ' is empty. It will be removed')
        os.rmdir(outTempFolder)


def clipQuads(inFolder, geoFolder, outFolder):
    # Clip downloaded quads using AOI geojson files
    bbox_names_list = list(set([f.split('_')[0] for f in os.listdir(inFolder)]))
    print('start clipping')
    if not os.path.exists(outFolder):
        os.makedirs(outFolder)
    for thisBbox in bbox_names_list:
        thisGeojson = [os.path.join(geoFolder, f) for f in os.listdir(geoFolder) if f.startswith(thisBbox)][0]
        # Find files for this AOI
        thisFiles = [f for f in os.listdir(inFolder) if f.startswith(thisBbox+'_')]
        for thisFile in thisFiles:
            source = os.path.join(inFolder, thisFile)
            output = os.path.join(outFolder, thisFile)
            gdal.Warp(srcDSOrSrcDSTab=source, destNameOrDestDS=output, cutlineDSName=thisGeojson,
                      cropToCutline=True)
    print('done clipping')


def mergeQuads(inFolder, outFolder):
    # merge tiles that belong to same AOI and same Date (year-month)
    bbox_names_list = list(set([f.split('_')[0] for f in os.listdir(inFolder)]))
    date_list = list(set(['_'.join(f.split('_')[1:3]) for f in os.listdir(inFolder)]))
    bbox_date_list = [b+'_'+d for b in bbox_names_list for d in date_list]
    if not os.path.exists(outFolder):
        os.makedirs(outFolder)
    for thisBboxDate in bbox_date_list:
        thisFiles = [f for f in os.listdir(inFolder) if f.startswith(thisBboxDate+'_')] # list all the files of a same bbox and same date
        input = [os.path.join(inFolder, f) for f in thisFiles]
        output = os.path.join(outFolder, thisBboxDate + '.tif')
        gdal.Warp(srcDSOrSrcDSTab = input, destNameOrDestDS = output)

# %%
#############################-----------MAIN-------#############################
start = 0
end = 10000

img_shapes = []
for i in range(start, end):
    thisbbox = bbox_list[i]
    print('{0}/{1} AOI:{2}, bbox:{3}'.format(i+1, len(bbox_list), bbox_names_list[i], thisbbox))
    outdir = bbox_names_list[i] # name of the AOI
    for thisMosaic in my_mosaics[:]:
#         tileSearch(thisMosaic,thisbbox) # not need to run-just sanity check
        tileDownload(thisMosaic, thisbbox, outdir) # uncomment when ready to start download!
        rename_files(outFolder, outFolder_renamed)
        clipQuads(outFolder_renamed, geojsonFolder, outFolder_clipped)
        mergeQuads(outFolder_clipped, outFolder_final)
        
        img_name = '{}_{}.tif'.format(outdir, '_'.join(thisMosaic.split('_')[2:4]))
        img = imageio.imread(os.path.join(outFolder_final, img_name))
        img_shapes.append(img.shape)
        
        delete_empty_folders(outFolder)
        shutil.rmtree(os.path.join(base_dir, 'temp_monthly_mosaics_renamed_clipped'))
        shutil.rmtree(os.path.join(base_dir, 'monthly_mosaics_renamed'))
        os.remove(os.path.join(outFolder_final, img_name))
# Out:
# 1/10000 AOI:00000, bbox:3.5311868000290234,45.17036008907887,3.6269314154800836,45.23786015657894
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.5311868000290234,45.17036008907887,3.6269314154800836,45.23786015657894 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00000/2019_10
# start clipping
# done clipping
# 2/10000 AOI:00001, bbox:0.5913378340082591,49.5571806594158,0.6953939894716906,49.62468072691587
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.5913378340082591,49.5571806594158,0.6953939894716906,49.62468072691587 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00001/2019_10
# start clipping
# done clipping
# 3/10000 AOI:00002, bbox:4.184957726518808,46.21563831090806,4.282508767763401,46.28313837840813
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.184957726518808,46.21563831090806,4.282508767763401,46.28313837840813 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00002/2019_10
# start clipping
# done clipping
# 4/10000 AOI:00003, bbox:1.5405553105508396,45.69436570538633,1.6371930387919371,45.7618657728864
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.5405553105508396,45.69436570538633,1.6371930387919371,45.7618657728864 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00003/2019_10
# start clipping
# done clipping
# 5/10000 AOI:00004, bbox:2.670917434814367,44.683271084209935,2.7658535954224717,44.750771151710005
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.670917434814367,44.683271084209935,2.7658535954224717,44.750771151710005 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00004/2019_10
# start clipping
# done clipping
# 6/10000 AOI:00005, bbox:-1.5433899098459682,49.26286741221873,-1.439955734391761,49.3303674797188
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.5433899098459682,49.26286741221873,-1.439955734391761,49.3303674797188 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00005/2019_10
# start clipping
# done clipping
# 7/10000 AOI:00006, bbox:4.856614309069188,48.612361937805304,4.958709244596646,48.679862005305374
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.856614309069188,48.612361937805304,4.958709244596646,48.679862005305374 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00006/2019_10
# start clipping
# done clipping
# 8/10000 AOI:00007, bbox:3.268474023696526,46.361416020273396,3.3662850325591207,46.428916087773466
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.268474023696526,46.361416020273396,3.3662850325591207,46.428916087773466 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00007/2019_10
# start clipping
# done clipping
# 9/10000 AOI:00008, bbox:6.275155640508282,44.88368217666796,6.3704219449901025,44.95118224416803
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.275155640508282,44.88368217666796,6.3704219449901025,44.95118224416803 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00008/2019_10
# start clipping
# done clipping
# 10/10000 AOI:00009, bbox:0.6712880434593238,44.68231211289607,0.7662226326116689,44.74981218039614
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.6712880434593238,44.68231211289607,0.7662226326116689,44.74981218039614 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00009/2019_10
# start clipping
# done clipping
# 11/10000 AOI:00010, bbox:-1.1101768785394013,45.78867659533554,-1.0133757715732417,45.85617666283561
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.1101768785394013,45.78867659533554,-1.0133757715732417,45.85617666283561 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00010/2019_10
# start clipping
# done clipping
# 12/10000 AOI:00011, bbox:0.6995524738844079,46.75374467996354,0.7980732465739253,46.82124474746361
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.6995524738844079,46.75374467996354,0.7980732465739253,46.82124474746361 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00011/2019_10
# start clipping
# done clipping
# 13/10000 AOI:00012, bbox:0.2381535923274356,47.08953435887787,0.3372937922669694,47.15703442637794
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.2381535923274356,47.08953435887787,0.3372937922669694,47.15703442637794 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00012/2019_10
# start clipping
# done clipping
# 14/10000 AOI:00013, bbox:-0.9083122597524405,43.49789746894442,-0.8152600101136365,43.56539753644449
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.9083122597524405,43.49789746894442,-0.8152600101136365,43.56539753644449 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00013/2019_10
# start clipping
# done clipping
# 15/10000 AOI:00014, bbox:3.701429226012677,45.94477461061862,3.7985025447388097,46.01227467811869
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.701429226012677,45.94477461061862,3.7985025447388097,46.01227467811869 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00014/2019_10
# start clipping
# done clipping
# 16/10000 AOI:00015, bbox:0.21784161895361542,49.360961895062815,0.3214819686686002,49.428461962562885
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.21784161895361542,49.360961895062815,0.3214819686686002,49.428461962562885 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00015/2019_10
# start clipping
# done clipping
# 17/10000 AOI:00016, bbox:-0.16996937968467307,46.269801445748556,-0.0723219837739407,46.337301513248626
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.16996937968467307,46.269801445748556,-0.0723219837739407,46.337301513248626 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00016/2019_10
# start clipping
# done clipping
# 18/10000 AOI:00017, bbox:5.949097694551642,48.810340164956465,6.0515951393066745,48.877840232456535
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.949097694551642,48.810340164956465,6.0515951393066745,48.877840232456535 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00017/2019_10
# start clipping
# done clipping
# 19/10000 AOI:00018, bbox:3.707306349464006,44.289866539415,3.801604387396518,44.35736660691507
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.707306349464006,44.289866539415,3.801604387396518,44.35736660691507 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00018/2019_10
# start clipping
# done clipping
# 20/10000 AOI:00019, bbox:2.5626237729016026,42.74489955321215,2.6545377655322024,42.81239962071222
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.5626237729016026,42.74489955321215,2.6545377655322024,42.81239962071222 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00019/2019_10
# start clipping
# done clipping
# 21/10000 AOI:00020, bbox:6.640096626691567,44.23570067206264,6.734307822888484,44.30320073956271
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.640096626691567,44.23570067206264,6.734307822888484,44.30320073956271 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00020/2019_10
# start clipping
# done clipping
# 22/10000 AOI:00021, bbox:6.992443533333611,47.696815067693365,7.092732819085741,47.764315135193435
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.992443533333611,47.696815067693365,7.092732819085741,47.764315135193435 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00021/2019_10
# start clipping
# done clipping
# 23/10000 AOI:00022, bbox:-4.32963642104289,48.609560001514126,-4.227547150706,48.677060069014196
# planet mosaics download global_monthly_2019_10_mosaic --bbox -4.32963642104289,48.609560001514126,-4.227547150706,48.677060069014196 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00022/2019_10
# start clipping
# done clipping
# 24/10000 AOI:00023, bbox:-0.5973813527100456,48.28312252402014,-0.495946171990098,48.350622591520214
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.5973813527100456,48.28312252402014,-0.495946171990098,48.350622591520214 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00023/2019_10
# start clipping
# done clipping
# 25/10000 AOI:00024, bbox:2.3088336698583314,42.79093415991227,2.40081599585043,42.85843422741234
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.3088336698583314,42.79093415991227,2.40081599585043,42.85843422741234 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00024/2019_10
# start clipping
# done clipping
# 26/10000 AOI:00025, bbox:2.176824597893102,50.14783017334004,2.2821603051986874,50.21533024084011
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.176824597893102,50.14783017334004,2.2821603051986874,50.21533024084011 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00025/2019_10
# start clipping
# done clipping
# 27/10000 AOI:00026, bbox:7.6892628093581274,48.854449273978446,7.791850532147394,48.921949341478516
# planet mosaics download global_monthly_2019_10_mosaic --bbox 7.6892628093581274,48.854449273978446,7.791850532147394,48.921949341478516 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00026/2019_10
# start clipping
# done clipping
# 28/10000 AOI:00027, bbox:1.0621075686930368,47.84084910342704,1.1626749789880868,47.90834917092711
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.0621075686930368,47.84084910342704,1.1626749789880868,47.90834917092711 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00027/2019_10
# start clipping
# done clipping
# 29/10000 AOI:00028, bbox:-0.8298319295141781,48.47584844615694,-0.7280119969186458,48.54334851365701
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.8298319295141781,48.47584844615694,-0.7280119969186458,48.54334851365701 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00028/2019_10
# start clipping
# done clipping
# 30/10000 AOI:00029, bbox:5.9054665210374475,46.999137971924085,6.004438868230259,47.066638039424156
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.9054665210374475,46.999137971924085,6.004438868230259,47.066638039424156 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00029/2019_10
# start clipping
# done clipping
# 31/10000 AOI:00030, bbox:-0.7034127115135105,46.72456783676074,-0.6049452363882076,46.79206790426081
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.7034127115135105,46.72456783676074,-0.6049452363882076,46.79206790426081 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00030/2019_10
# start clipping
# done clipping
# 32/10000 AOI:00031, bbox:-0.49692139292115733,42.924286231534545,-0.4047402091721872,42.991786299034615
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.49692139292115733,42.924286231534545,-0.4047402091721872,42.991786299034615 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00031/2019_10
# start clipping
# done clipping
# 33/10000 AOI:00032, bbox:2.6642883510227904,46.49588897074606,2.762340963409079,46.56338903824613
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.6642883510227904,46.49588897074606,2.762340963409079,46.56338903824613 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00032/2019_10
# start clipping
# done clipping
# 34/10000 AOI:00033, bbox:2.521805946080721,42.58978928081281,2.6134908747659846,42.65728934831288
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.521805946080721,42.58978928081281,2.6134908747659846,42.65728934831288 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00033/2019_10
# start clipping
# done clipping
# 35/10000 AOI:00034, bbox:1.234860288882043,43.78198779359315,1.3283535639971298,43.84948786109322
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.234860288882043,43.78198779359315,1.3283535639971298,43.84948786109322 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00034/2019_10
# start clipping
# done clipping
# 36/10000 AOI:00035, bbox:5.697907339581845,46.022092336252314,5.7951163243873305,46.089592403752384
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.697907339581845,46.022092336252314,5.7951163243873305,46.089592403752384 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00035/2019_10
# start clipping
# done clipping
# 37/10000 AOI:00036, bbox:-1.238145151397804,45.90206600185587,-1.1411465337359992,45.96956606935594
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.238145151397804,45.90206600185587,-1.1411465337359992,45.96956606935594 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00036/2019_10
# start clipping
# done clipping
# 38/10000 AOI:00037, bbox:0.9938271289420593,46.42524695584395,1.0917526050636928,46.49274702334402
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.9938271289420593,46.42524695584395,1.0917526050636928,46.49274702334402 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00037/2019_10
# start clipping
# done clipping
# 39/10000 AOI:00038, bbox:5.489003954523368,46.56740534869522,5.587185765736915,46.63490541619529
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.489003954523368,46.56740534869522,5.587185765736915,46.63490541619529 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00038/2019_10
# start clipping
# done clipping
# 40/10000 AOI:00039, bbox:-2.5819418744242126,47.66830234736411,-2.4817073883928478,47.73580241486418
# planet mosaics download global_monthly_2019_10_mosaic --bbox -2.5819418744242126,47.66830234736411,-2.4817073883928478,47.73580241486418 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00039/2019_10
# start clipping
# done clipping
# 41/10000 AOI:00040, bbox:7.658308280402815,49.03040089030341,7.761258319823067,49.09790095780348
# planet mosaics download global_monthly_2019_10_mosaic --bbox 7.658308280402815,49.03040089030341,7.761258319823067,49.09790095780348 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00040/2019_10
# start clipping
# done clipping
# 42/10000 AOI:00041, bbox:6.475370144871795,43.75605036394626,6.568822885616005,43.82355043144633
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.475370144871795,43.75605036394626,6.568822885616005,43.82355043144633 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00041/2019_10
# start clipping
# done clipping
# 43/10000 AOI:00042, bbox:5.365439897832082,48.46073950972861,5.467229520369976,48.52823957722868
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.365439897832082,48.46073950972861,5.467229520369976,48.52823957722868 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00042/2019_10
# start clipping
# done clipping
# 44/10000 AOI:00043, bbox:2.1947723249233517,45.290333020234634,2.2907192543053325,45.357833087734704
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.1947723249233517,45.290333020234634,2.2907192543053325,45.357833087734704 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00043/2019_10
# start clipping
# done clipping
# 45/10000 AOI:00044, bbox:0.5709402266014632,48.93261705991396,0.673688476278715,49.00011712741403
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.5709402266014632,48.93261705991396,0.673688476278715,49.00011712741403 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00044/2019_10
# start clipping
# done clipping
# 46/10000 AOI:00045, bbox:1.8812134312966426,46.89467020834076,1.9799928095672792,46.96217027584083
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.8812134312966426,46.89467020834076,1.9799928095672792,46.96217027584083 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00045/2019_10
# start clipping
# done clipping
# 47/10000 AOI:00046, bbox:8.955790552712333,41.99381224369025,9.04661202177892,42.06131231119032
# planet mosaics download global_monthly_2019_10_mosaic --bbox 8.955790552712333,41.99381224369025,9.04661202177892,42.06131231119032 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00046/2019_10
# start clipping
# done clipping
# 48/10000 AOI:00047, bbox:2.8636309566217912,43.961210454455426,2.957405806562229,44.028710521955496
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.8636309566217912,43.961210454455426,2.957405806562229,44.028710521955496 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00047/2019_10
# start clipping
# done clipping
# 49/10000 AOI:00048, bbox:-0.501764465473256,44.312039942441025,-0.4074308073713218,44.379540009941095
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.501764465473256,44.312039942441025,-0.4074308073713218,44.379540009941095 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00048/2019_10
# start clipping
# done clipping
# 50/10000 AOI:00049, bbox:4.939302948440864,44.49070232445985,5.03392511956577,44.558202391959924
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.939302948440864,44.49070232445985,5.03392511956577,44.558202391959924 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00049/2019_10
# start clipping
# done clipping
# 51/10000 AOI:00050, bbox:-1.7318286332478725,47.36777840267404,-1.6321666198298086,47.43527847017411
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.7318286332478725,47.36777840267404,-1.6321666198298086,47.43527847017411 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00050/2019_10
# start clipping
# done clipping
# 52/10000 AOI:00051, bbox:5.518643499639958,43.26903321749586,5.61134512294381,43.33653328499593
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.518643499639958,43.26903321749586,5.61134512294381,43.33653328499593 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00051/2019_10
# start clipping
# done clipping
# 53/10000 AOI:00052, bbox:6.546810101136889,47.60958989451018,6.646932011826251,47.67708996201025
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.546810101136889,47.60958989451018,6.646932011826251,47.67708996201025 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00052/2019_10
# start clipping
# done clipping
# 54/10000 AOI:00053, bbox:-3.1729833926796696,47.74179059901594,-3.072607494205717,47.80929066651601
# planet mosaics download global_monthly_2019_10_mosaic --bbox -3.1729833926796696,47.74179059901594,-3.072607494205717,47.80929066651601 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00053/2019_10
# start clipping
# done clipping
# 55/10000 AOI:00054, bbox:3.094153440179082,46.98875935990554,3.1931065679411814,47.056259427405614
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.094153440179082,46.98875935990554,3.1931065679411814,47.056259427405614 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00054/2019_10
# start clipping
# done clipping
# 56/10000 AOI:00055, bbox:6.320023272665677,46.75802427730882,6.4185518699302655,46.82552434480889
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.320023272665677,46.75802427730882,6.4185518699302655,46.82552434480889 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00055/2019_10
# start clipping
# done clipping
# 57/10000 AOI:00056, bbox:5.4039097248210615,43.634358220134075,5.497173011262628,43.701858287634145
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.4039097248210615,43.634358220134075,5.497173011262628,43.701858287634145 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00056/2019_10
# start clipping
# done clipping
# 58/10000 AOI:00057, bbox:0.7150043265499297,44.17668287071614,0.8091211796821075,44.24418293821621
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.7150043265499297,44.17668287071614,0.8091211796821075,44.24418293821621 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00057/2019_10
# start clipping
# done clipping
# 59/10000 AOI:00058, bbox:-1.7875174887182097,48.46506727104701,-1.685719186820258,48.53256733854708
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.7875174887182097,48.46506727104701,-1.685719186820258,48.53256733854708 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00058/2019_10
# start clipping
# done clipping
# 60/10000 AOI:00059, bbox:3.839181009053486,44.2142571734345,3.933357893261487,44.28175724093457
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.839181009053486,44.2142571734345,3.933357893261487,44.28175724093457 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00059/2019_10
# start clipping
# done clipping
# 61/10000 AOI:00060, bbox:4.9581653974530715,49.49144520973334,5.062081746444649,49.55894527723341
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.9581653974530715,49.49144520973334,5.062081746444649,49.55894527723341 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00060/2019_10
# start clipping
# done clipping
# 62/10000 AOI:00061, bbox:0.6893851082489526,48.214493333260755,0.7906842571268069,48.281993400760825
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.6893851082489526,48.214493333260755,0.7906842571268069,48.281993400760825 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00061/2019_10
# start clipping
# done clipping
# 63/10000 AOI:00062, bbox:7.240131042262566,48.39281165720722,7.341784704532215,48.46031172470729
# planet mosaics download global_monthly_2019_10_mosaic --bbox 7.240131042262566,48.39281165720722,7.341784704532215,48.46031172470729 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00062/2019_10
# start clipping
# done clipping
# 64/10000 AOI:00063, bbox:6.424741980485417,43.710668539918004,6.518123930129499,43.778168607418074
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.424741980485417,43.710668539918004,6.518123930129499,43.778168607418074 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00063/2019_10
# start clipping
# done clipping
# 65/10000 AOI:00064, bbox:2.9162818824390575,46.4595546992127,3.01426904328813,46.52705476671277
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.9162818824390575,46.4595546992127,3.01426904328813,46.52705476671277 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00064/2019_10
# start clipping
# done clipping
# 66/10000 AOI:00065, bbox:5.0883008493217465,49.29585013300215,5.191804222169183,49.36335020050222
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.0883008493217465,49.29585013300215,5.191804222169183,49.36335020050222 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00065/2019_10
# start clipping
# done clipping
# 67/10000 AOI:00066, bbox:5.427579652142623,48.286134204870436,5.529020814103367,48.353634272370506
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.427579652142623,48.286134204870436,5.529020814103367,48.353634272370506 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00066/2019_10
# start clipping
# done clipping
# 68/10000 AOI:00067, bbox:6.59861899649801,46.03926979189612,6.695858197398149,46.10676985939619
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.59861899649801,46.03926979189612,6.695858197398149,46.10676985939619 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00067/2019_10
# start clipping
# done clipping
# 69/10000 AOI:00068, bbox:4.93882247149961,48.31866083985977,5.040328294673703,48.38616090735984
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.93882247149961,48.31866083985977,5.040328294673703,48.38616090735984 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00068/2019_10
# start clipping
# done clipping
# 70/10000 AOI:00069, bbox:4.481945703528271,46.630591636723864,4.580242075950379,46.698091704223934
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.481945703528271,46.630591636723864,4.580242075950379,46.698091704223934 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00069/2019_10
# start clipping
# done clipping
# 71/10000 AOI:00070, bbox:5.201357411576443,46.253854411268634,5.298976409341575,46.321354478768704
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.201357411576443,46.253854411268634,5.298976409341575,46.321354478768704 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00070/2019_10
# start clipping
# done clipping
# 72/10000 AOI:00071, bbox:1.494425685130734,48.180496723506266,1.5956576371670177,48.24799679100634
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.494425685130734,48.180496723506266,1.5956576371670177,48.24799679100634 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00071/2019_10
# start clipping
# done clipping
# 73/10000 AOI:00072, bbox:5.937837880115139,45.09843758603226,6.033461819746198,45.16593765353233
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.937837880115139,45.09843758603226,6.033461819746198,45.16593765353233 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00072/2019_10
# start clipping
# done clipping
# 74/10000 AOI:00073, bbox:-1.3650369730828036,47.63454030612305,-1.2648672662010059,47.70204037362312
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.3650369730828036,47.63454030612305,-1.2648672662010059,47.70204037362312 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00073/2019_10
# start clipping
# done clipping
# 75/10000 AOI:00074, bbox:1.5422715902335922,44.202686352052,1.6364299756936878,44.27018641955207
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.5422715902335922,44.202686352052,1.6364299756936878,44.27018641955207 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00074/2019_10
# start clipping
# done clipping
# 76/10000 AOI:00075, bbox:3.825828778526062,45.697713974965325,3.922472293192023,45.765214042465395
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.825828778526062,45.697713974965325,3.922472293192023,45.765214042465395 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00075/2019_10
# start clipping
# done clipping
# 77/10000 AOI:00076, bbox:5.7806612315366275,47.531939121814716,5.880634803334663,47.599439189314786
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.7806612315366275,47.531939121814716,5.880634803334663,47.599439189314786 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00076/2019_10
# start clipping
# done clipping
# 78/10000 AOI:00077, bbox:2.374860996082935,46.440076221779236,2.4728131211260007,46.50757628927931
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.374860996082935,46.440076221779236,2.4728131211260007,46.50757628927931 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00077/2019_10
# start clipping
# done clipping
# 79/10000 AOI:00078, bbox:-0.5561981481051168,46.61684409674717,-0.4579267338702642,46.68434416424724
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.5561981481051168,46.61684409674717,-0.4579267338702642,46.68434416424724 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00078/2019_10
# start clipping
# done clipping
# 80/10000 AOI:00079, bbox:3.4482933420655,50.07006512664486,3.5534581465762884,50.13756519414493
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.4482933420655,50.07006512664486,3.5534581465762884,50.13756519414493 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00079/2019_10
# start clipping
# done clipping
# 81/10000 AOI:00080, bbox:4.694061741359287,46.545133003471754,4.792203263294322,46.612633070971825
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.694061741359287,46.545133003471754,4.792203263294322,46.612633070971825 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00080/2019_10
# start clipping
# done clipping
# 82/10000 AOI:00081, bbox:6.364095048118361,45.674069085925474,6.460697721957651,45.741569153425544
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.364095048118361,45.674069085925474,6.460697721957651,45.741569153425544 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00081/2019_10
# start clipping
# done clipping
# 83/10000 AOI:00082, bbox:2.8409960523564104,49.22680393035139,2.9443547119990896,49.29430399785146
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.8409960523564104,49.22680393035139,2.9443547119990896,49.29430399785146 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00082/2019_10
# start clipping
# done clipping
# 84/10000 AOI:00083, bbox:-1.3510976344526235,43.27112757939507,-1.2583928212064661,43.33862764689514
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.3510976344526235,43.27112757939507,-1.2583928212064661,43.33862764689514 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00083/2019_10
# start clipping
# done clipping
# 85/10000 AOI:00084, bbox:5.549198333589437,49.17757145234814,5.652454145771198,49.24507151984821
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.549198333589437,49.17757145234814,5.652454145771198,49.24507151984821 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00084/2019_10
# start clipping
# done clipping
# 86/10000 AOI:00085, bbox:1.576114147735031,47.64469422709092,1.6763033244576446,47.712194294590994
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.576114147735031,47.64469422709092,1.6763033244576446,47.712194294590994 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00085/2019_10
# start clipping
# done clipping
# 87/10000 AOI:00086, bbox:6.147923841752976,45.89769842585127,6.24491482966096,45.96519849335134
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.147923841752976,45.89769842585127,6.24491482966096,45.96519849335134 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00086/2019_10
# start clipping
# done clipping
# 88/10000 AOI:00087, bbox:2.814635544871037,49.78589117083232,2.919182144228065,49.85339123833239
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.814635544871037,49.78589117083232,2.919182144228065,49.85339123833239 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00087/2019_10
# start clipping
# done clipping
# 89/10000 AOI:00088, bbox:4.127518827499888,46.928609628656694,4.226360778789837,46.996109696156765
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.127518827499888,46.928609628656694,4.226360778789837,46.996109696156765 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00088/2019_10
# start clipping
# done clipping
# 90/10000 AOI:00089, bbox:3.0838364563058436,50.20324410213438,3.189294403790666,50.27074416963445
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.0838364563058436,50.20324410213438,3.189294403790666,50.27074416963445 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00089/2019_10
# start clipping
# done clipping
# 91/10000 AOI:00090, bbox:-0.5625358130808413,43.109438024575304,-0.47007626390266033,43.176938092075375
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.5625358130808413,43.109438024575304,-0.47007626390266033,43.176938092075375 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00090/2019_10
# start clipping
# done clipping
# 92/10000 AOI:00091, bbox:1.9677932209934363,43.67237415775035,2.061115564131455,43.73987422525042
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.9677932209934363,43.67237415775035,2.061115564131455,43.73987422525042 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00091/2019_10
# start clipping
# done clipping
# 93/10000 AOI:00092, bbox:4.3300737310008595,45.648398712469465,4.426632123150696,45.715898779969535
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.3300737310008595,45.648398712469465,4.426632123150696,45.715898779969535 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00092/2019_10
# start clipping
# done clipping
# 94/10000 AOI:00093, bbox:5.809395662922422,47.06755778694468,5.908494980549491,47.13505785444475
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.809395662922422,47.06755778694468,5.908494980549491,47.13505785444475 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00093/2019_10
# start clipping
# done clipping
# 95/10000 AOI:00094, bbox:-1.2440563644655591,47.44673402921775,-1.1442448472606852,47.51423409671782
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.2440563644655591,47.44673402921775,-1.1442448472606852,47.51423409671782 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00094/2019_10
# start clipping
# done clipping
# 96/10000 AOI:00095, bbox:4.75927817897657,43.682849402093346,4.852616815483653,43.75034946959342
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.75927817897657,43.682849402093346,4.852616815483653,43.75034946959342 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00095/2019_10
# start clipping
# done clipping
# 97/10000 AOI:00096, bbox:5.089305732976501,48.44352417878924,5.191060850424612,48.51102424628931
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.089305732976501,48.44352417878924,5.191060850424612,48.51102424628931 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00096/2019_10
# start clipping
# done clipping
# 98/10000 AOI:00097, bbox:-0.06699530976036172,46.851493385480644,0.03170462921690667,46.918993452980715
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.06699530976036172,46.851493385480644,0.03170462921690667,46.918993452980715 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00097/2019_10
# start clipping
# done clipping
# 99/10000 AOI:00098, bbox:-1.0513643447062755,47.37420552365592,-0.951690185248884,47.44170559115599
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.0513643447062755,47.37420552365592,-0.951690185248884,47.44170559115599 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00098/2019_10
# start clipping
# done clipping
# 100/10000 AOI:00099, bbox:5.293306343122857,44.583556459291806,5.38807952251559,44.651056526791876
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.293306343122857,44.583556459291806,5.38807952251559,44.651056526791876 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00099/2019_10
# start clipping
# done clipping
# 101/10000 AOI:00100, bbox:0.3166013509299521,43.50015415710771,0.4096570784850056,43.56765422460778
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.3166013509299521,43.50015415710771,0.4096570784850056,43.56765422460778 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00100/2019_10
# start clipping
# done clipping
# 102/10000 AOI:00101, bbox:4.156946245824716,45.29643585074039,4.252903500700577,45.36393591824046
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.156946245824716,45.29643585074039,4.252903500700577,45.36393591824046 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00101/2019_10
# start clipping
# done clipping
# 103/10000 AOI:00102, bbox:-0.1734527222888831,45.54379428692398,-0.07707415523443986,45.611294354424054
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.1734527222888831,45.54379428692398,-0.07707415523443986,45.611294354424054 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00102/2019_10
# start clipping
# done clipping
# 104/10000 AOI:00103, bbox:-2.5722933231278358,48.23522870526698,-2.470953127894439,48.30272877276705
# planet mosaics download global_monthly_2019_10_mosaic --bbox -2.5722933231278358,48.23522870526698,-2.470953127894439,48.30272877276705 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00103/2019_10
# start clipping
# done clipping
# 105/10000 AOI:00104, bbox:4.744538647346164,47.20774288822528,4.8438995779667025,47.27524295572535
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.744538647346164,47.20774288822528,4.8438995779667025,47.27524295572535 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00104/2019_10
# start clipping
# done clipping
# 106/10000 AOI:00105, bbox:1.2192650412555883,46.28427834028034,1.3169382381831807,46.35177840778041
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.2192650412555883,46.28427834028034,1.3169382381831807,46.35177840778041 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00105/2019_10
# start clipping
# done clipping
# 107/10000 AOI:00106, bbox:0.31239325999508694,47.59855710972222,0.4124940563500288,47.66605717722229
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.31239325999508694,47.59855710972222,0.4124940563500288,47.66605717722229 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00106/2019_10
# start clipping
# done clipping
# 108/10000 AOI:00107, bbox:2.1960905797372217,50.4508037220228,2.3020993292934064,50.51830378952287
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.1960905797372217,50.4508037220228,2.3020993292934064,50.51830378952287 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00107/2019_10
# start clipping
# done clipping
# 109/10000 AOI:00108, bbox:4.5503559558927344,49.772770487734924,4.6548742493621456,49.840270555234994
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.5503559558927344,49.772770487734924,4.6548742493621456,49.840270555234994 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00108/2019_10
# start clipping
# done clipping
# 110/10000 AOI:00109, bbox:-0.8292298040389028,44.61962841310373,-0.734397763679134,44.6871284806038
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.8292298040389028,44.61962841310373,-0.734397763679134,44.6871284806038 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00109/2019_10
# start clipping
# done clipping
# 111/10000 AOI:00110, bbox:1.8517403920444329,43.71883413935808,1.9451350669699425,43.78633420685815
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.8517403920444329,43.71883413935808,1.9451350669699425,43.78633420685815 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00110/2019_10
# start clipping
# done clipping
# 112/10000 AOI:00111, bbox:2.7378089837548396,43.03164196559646,2.830151248865167,43.09914203309653
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.7378089837548396,43.03164196559646,2.830151248865167,43.09914203309653 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00111/2019_10
# start clipping
# done clipping
# 113/10000 AOI:00112, bbox:5.5905322805226705,43.319965650275385,5.683311576961728,43.387465717775456
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.5905322805226705,43.319965650275385,5.683311576961728,43.387465717775456 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00112/2019_10
# start clipping
# done clipping
# 114/10000 AOI:00113, bbox:2.0903442622102997,48.15578644895438,2.191527450806562,48.22328651645445
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.0903442622102997,48.15578644895438,2.191527450806562,48.22328651645445 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00113/2019_10
# start clipping
# done clipping
# 115/10000 AOI:00114, bbox:2.744746560251131,48.88371125294416,2.847394294865866,48.95121132044423
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.744746560251131,48.88371125294416,2.847394294865866,48.95121132044423 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00114/2019_10
# start clipping
# done clipping
# 116/10000 AOI:00115, bbox:-1.1201740534840203,46.64618294259289,-1.0218493533825248,46.71368301009296
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.1201740534840203,46.64618294259289,-1.0218493533825248,46.71368301009296 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00115/2019_10
# start clipping
# done clipping
# 117/10000 AOI:00116, bbox:1.2554595167921025,48.68611056436032,1.3577038778979202,48.75361063186039
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.2554595167921025,48.68611056436032,1.3577038778979202,48.75361063186039 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00116/2019_10
# start clipping
# done clipping
# 118/10000 AOI:00117, bbox:5.337137330042384,46.514608189948305,5.435223712247486,46.582108257448375
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.337137330042384,46.514608189948305,5.435223712247486,46.582108257448375 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00117/2019_10
# start clipping
# done clipping
# 119/10000 AOI:00118, bbox:3.123469152238477,44.22880436697138,3.2176693094117277,44.29630443447145
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.123469152238477,44.22880436697138,3.2176693094117277,44.29630443447145 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00118/2019_10
# start clipping
# done clipping
# 120/10000 AOI:00119, bbox:0.8230564505231808,45.98543874156074,0.9202010515511364,46.05293880906081
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.8230564505231808,45.98543874156074,0.9202010515511364,46.05293880906081 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00119/2019_10
# start clipping
# done clipping
# 121/10000 AOI:00120, bbox:2.8865150239715556,47.73630670844528,2.986880350391121,47.80380677594535
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.8865150239715556,47.73630670844528,2.986880350391121,47.80380677594535 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00120/2019_10
# start clipping
# done clipping
# 122/10000 AOI:00121, bbox:0.9454536059278649,48.67399490432561,1.0476733772738358,48.74149497182568
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.9454536059278649,48.67399490432561,1.0476733772738358,48.74149497182568 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00121/2019_10
# start clipping
# done clipping
# 123/10000 AOI:00122, bbox:2.870523573215036,50.67313845020125,2.977033631623064,50.74063851770132
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.870523573215036,50.67313845020125,2.977033631623064,50.74063851770132 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00122/2019_10
# start clipping
# done clipping
# 124/10000 AOI:00123, bbox:2.3370055109077548,45.7610266191548,2.4337586342782456,45.82852668665487
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.3370055109077548,45.7610266191548,2.4337586342782456,45.82852668665487 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00123/2019_10
# start clipping
# done clipping
# 125/10000 AOI:00124, bbox:3.177821844374212,49.245205179780854,3.2812190167610424,49.312705247280924
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.177821844374212,49.245205179780854,3.2812190167610424,49.312705247280924 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00124/2019_10
# start clipping
# done clipping
# 126/10000 AOI:00125, bbox:-0.13404486961381856,44.20321552498358,-0.03988563838556897,44.27071559248365
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.13404486961381856,44.20321552498358,-0.03988563838556897,44.27071559248365 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00125/2019_10
# start clipping
# done clipping
# 127/10000 AOI:00126, bbox:2.9858796917985506,48.9750192397474,3.088715309929365,49.04251930724747
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.9858796917985506,48.9750192397474,3.088715309929365,49.04251930724747 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00126/2019_10
# start clipping
# done clipping
# 128/10000 AOI:00127, bbox:4.692218984406321,49.61801048442669,4.796404970901327,49.68551055192676
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.692218984406321,49.61801048442669,4.796404970901327,49.68551055192676 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00127/2019_10
# start clipping
# done clipping
# 129/10000 AOI:00128, bbox:0.15415854157103226,48.0071181959499,0.25504973110805523,48.07461826344997
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.15415854157103226,48.0071181959499,0.25504973110805523,48.07461826344997 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00128/2019_10
# start clipping
# done clipping
# 130/10000 AOI:00129, bbox:1.2520547165875158,42.84827736439014,1.3441223877636967,42.91577743189021
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.2520547165875158,42.84827736439014,1.3441223877636967,42.91577743189021 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00129/2019_10
# start clipping
# done clipping
# 131/10000 AOI:00130, bbox:-1.1510276869461706,47.33812149414562,-1.0514216649083983,47.40562156164569
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.1510276869461706,47.33812149414562,-1.0514216649083983,47.40562156164569 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00130/2019_10
# start clipping
# done clipping
# 132/10000 AOI:00131, bbox:6.636596581868555,44.62819748998936,6.731442621228271,44.69569755748943
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.636596581868555,44.62819748998936,6.731442621228271,44.69569755748943 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00131/2019_10
# start clipping
# done clipping
# 133/10000 AOI:00132, bbox:6.912480139234803,45.19979662112238,7.008274276487826,45.26729668862245
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.912480139234803,45.19979662112238,7.008274276487826,45.26729668862245 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00132/2019_10
# start clipping
# done clipping
# 134/10000 AOI:00133, bbox:2.467449252924265,44.964141759268955,2.5628490770886647,45.031641826769025
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.467449252924265,44.964141759268955,2.5628490770886647,45.031641826769025 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00133/2019_10
# start clipping
# done clipping
# 135/10000 AOI:00134, bbox:2.0314718840299877,49.077517876218835,2.1345195460517146,49.145017943718905
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.0314718840299877,49.077517876218835,2.1345195460517146,49.145017943718905 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00134/2019_10
# start clipping
# done clipping
# 136/10000 AOI:00135, bbox:1.6192887800644318,50.38055038354746,1.7251404362514213,50.44805045104753
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.6192887800644318,50.38055038354746,1.7251404362514213,50.44805045104753 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00135/2019_10
# start clipping
# done clipping
# 137/10000 AOI:00136, bbox:-0.17512383850214697,44.048982606058885,-0.08121013517392821,44.116482673558956
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.17512383850214697,44.048982606058885,-0.08121013517392821,44.116482673558956 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00136/2019_10
# start clipping
# done clipping
# 138/10000 AOI:00137, bbox:9.405181445293376,42.94076903947712,9.497387303032626,43.00826910697719
# planet mosaics download global_monthly_2019_10_mosaic --bbox 9.405181445293376,42.94076903947712,9.497387303032626,43.00826910697719 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00137/2019_10
# start clipping
# done clipping
# 139/10000 AOI:00138, bbox:2.7294297348812915,45.2258938148444,2.8252678401107048,45.29339388234447
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.7294297348812915,45.2258938148444,2.8252678401107048,45.29339388234447 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00138/2019_10
# start clipping
# done clipping
# 140/10000 AOI:00139, bbox:-4.360454399339882,48.47944592257326,-4.258627246137372,48.54694599007333
# planet mosaics download global_monthly_2019_10_mosaic --bbox -4.360454399339882,48.47944592257326,-4.258627246137372,48.54694599007333 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00139/2019_10
# start clipping
# done clipping
# 141/10000 AOI:00140, bbox:2.948638708937046,47.63443839050747,3.048808220452991,47.70193845800754
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.948638708937046,47.63443839050747,3.048808220452991,47.70193845800754 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00140/2019_10
# start clipping
# done clipping
# 142/10000 AOI:00141, bbox:-0.8580839224054992,46.08945937366214,-0.7607562773750111,46.15695944116221
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.8580839224054992,46.08945937366214,-0.7607562773750111,46.15695944116221 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/00141/2019_10
# start clipping
# ...
# done clipping
# 9954/10000 AOI:09953, bbox:2.1879733943115314,42.624297775871455,2.2797091275704306,42.691797843371525
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.1879733943115314,42.624297775871455,2.2797091275704306,42.691797843371525 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09953/2019_10
# start clipping
# done clipping
# 9955/10000 AOI:09954, bbox:-2.1035335493129117,47.66986993033693,-2.003296052682598,47.737369997837
# planet mosaics download global_monthly_2019_10_mosaic --bbox -2.1035335493129117,47.66986993033693,-2.003296052682598,47.737369997837 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09954/2019_10
# start clipping
# done clipping
# 9956/10000 AOI:09955, bbox:-0.29511568018056167,42.976563519138274,-0.2028561679622096,43.044063586638345
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.29511568018056167,42.976563519138274,-0.2028561679622096,43.044063586638345 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09955/2019_10
# start clipping
# done clipping
# 9957/10000 AOI:09956, bbox:1.8079699783304886,50.63804440653352,1.9144004869759248,50.70554447403359
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.8079699783304886,50.63804440653352,1.9144004869759248,50.70554447403359 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09956/2019_10
# start clipping
# done clipping
# 9958/10000 AOI:09957, bbox:1.3860788330266605,47.62456032670825,1.4862294140322712,47.69206039420832
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.3860788330266605,47.62456032670825,1.4862294140322712,47.69206039420832 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09957/2019_10
# start clipping
# done clipping
# 9959/10000 AOI:09958, bbox:1.6925391276016768,43.473956931156906,1.7855545059394258,43.541456998656976
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.6925391276016768,43.473956931156906,1.7855545059394258,43.541456998656976 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09958/2019_10
# start clipping
# done clipping
# 9960/10000 AOI:09959, bbox:4.611652530328818,44.82093151589415,4.7068150916440175,44.88843158339422
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.611652530328818,44.82093151589415,4.7068150916440175,44.88843158339422 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09959/2019_10
# start clipping
# done clipping
# 9961/10000 AOI:09960, bbox:3.1918959108460045,50.496806789707996,3.2980078671945248,50.56430685720807
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.1918959108460045,50.496806789707996,3.2980078671945248,50.56430685720807 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09960/2019_10
# start clipping
# done clipping
# 9962/10000 AOI:09961, bbox:3.2634466420573416,44.724236495798685,3.3584500057124074,44.791736563298755
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.2634466420573416,44.724236495798685,3.3584500057124074,44.791736563298755 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09961/2019_10
# start clipping
# done clipping
# 9963/10000 AOI:09962, bbox:2.3196710784793293,46.75910335198631,2.4182016489463463,46.82660341948638
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.3196710784793293,46.75910335198631,2.4182016489463463,46.82660341948638 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09962/2019_10
# start clipping
# done clipping
# 9964/10000 AOI:09963, bbox:5.949419116594995,47.27810062654773,6.0489120947584265,47.3456006940478
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.949419116594995,47.27810062654773,6.0489120947584265,47.3456006940478 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09963/2019_10
# start clipping
# done clipping
# 9965/10000 AOI:09964, bbox:4.669537030867278,49.203619135114664,4.77284722207485,49.271119202614734
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.669537030867278,49.203619135114664,4.77284722207485,49.271119202614734 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09964/2019_10
# start clipping
# done clipping
# 9966/10000 AOI:09965, bbox:2.9201678413329626,48.261528584705246,3.0215601650372648,48.32902865220532
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.9201678413329626,48.261528584705246,3.0215601650372648,48.32902865220532 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09965/2019_10
# start clipping
# done clipping
# 9967/10000 AOI:09966, bbox:4.7830464466659395,49.84354550491415,4.887717673550008,49.91104557241422
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.7830464466659395,49.84354550491415,4.887717673550008,49.91104557241422 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09966/2019_10
# start clipping
# done clipping
# 9968/10000 AOI:09967, bbox:1.4053957270939517,43.17962910142757,1.4979614977708924,43.24712916892764
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.4053957270939517,43.17962910142757,1.4979614977708924,43.24712916892764 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09967/2019_10
# start clipping
# done clipping
# 9969/10000 AOI:09968, bbox:-1.511121889688631,48.781093018788766,-1.4086841840094404,48.84859308628884
# planet mosaics download global_monthly_2019_10_mosaic --bbox -1.511121889688631,48.781093018788766,-1.4086841840094404,48.84859308628884 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09968/2019_10
# start clipping
# done clipping
# 9970/10000 AOI:09969, bbox:0.40668433715638574,45.86001143704627,0.5036095625744348,45.92751150454634
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.40668433715638574,45.86001143704627,0.5036095625744348,45.92751150454634 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09969/2019_10
# start clipping
# done clipping
# 9971/10000 AOI:09970, bbox:5.502855048692417,46.096375074861264,5.600194899049162,46.163875142361334
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.502855048692417,46.096375074861264,5.600194899049162,46.163875142361334 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09970/2019_10
# start clipping
# done clipping
# 9972/10000 AOI:09971, bbox:4.928518818889178,43.51866174895753,5.021603084855796,43.5861618164576
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.928518818889178,43.51866174895753,5.021603084855796,43.5861618164576 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09971/2019_10
# start clipping
# done clipping
# 9973/10000 AOI:09972, bbox:5.336082500304545,46.25761473702509,5.433708192209468,46.32511480452516
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.336082500304545,46.25761473702509,5.433708192209468,46.32511480452516 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09972/2019_10
# start clipping
# done clipping
# 9974/10000 AOI:09973, bbox:4.897072402892438,48.46696320293722,4.998874507746245,48.53446327043729
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.897072402892438,48.46696320293722,4.998874507746245,48.53446327043729 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09973/2019_10
# start clipping
# done clipping
# 9975/10000 AOI:09974, bbox:1.1764719089232907,46.8358451549616,1.2751431027161944,46.903345222461674
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.1764719089232907,46.8358451549616,1.2751431027161944,46.903345222461674 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09974/2019_10
# start clipping
# done clipping
# 9976/10000 AOI:09975, bbox:0.2372925993630126,47.26222332354464,0.33675573520997293,47.32972339104471
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.2372925993630126,47.26222332354464,0.33675573520997293,47.32972339104471 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09975/2019_10
# start clipping
# done clipping
# 9977/10000 AOI:09976, bbox:0.1350200702726072,44.55426709616394,0.2297455376246802,44.62176716366401
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.1350200702726072,44.55426709616394,0.2297455376246802,44.62176716366401 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09976/2019_10
# start clipping
# done clipping
# 9978/10000 AOI:09977, bbox:3.3827962708021433,48.07902296630603,3.483828392705072,48.1465230338061
# planet mosaics download global_monthly_2019_10_mosaic --bbox 3.3827962708021433,48.07902296630603,3.483828392705072,48.1465230338061 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09977/2019_10
# start clipping
# done clipping
# 9979/10000 AOI:09978, bbox:5.283116705296309,47.444007027615115,5.382923048238937,47.511507095115185
# planet mosaics download global_monthly_2019_10_mosaic --bbox 5.283116705296309,47.444007027615115,5.382923048238937,47.511507095115185 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09978/2019_10
# start clipping
# done clipping
# 9980/10000 AOI:09979, bbox:4.891113010197087,48.13728542758463,4.992259731794338,48.2047854950847
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.891113010197087,48.13728542758463,4.992259731794338,48.2047854950847 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09979/2019_10
# start clipping
# done clipping
# 9981/10000 AOI:09980, bbox:1.3423233113169761,46.319512175040174,1.4400593858003568,46.387012242540244
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.3423233113169761,46.319512175040174,1.4400593858003568,46.387012242540244 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09980/2019_10
# start clipping
# done clipping
# 9982/10000 AOI:09981, bbox:1.1557754835124365,47.42191754992729,1.2555399415717046,47.48941761742736
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.1557754835124365,47.42191754992729,1.2555399415717046,47.48941761742736 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09981/2019_10
# start clipping
# done clipping
# 9983/10000 AOI:09982, bbox:1.596908583518113,47.32690794456406,1.6964934580375015,47.39440801206413
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.596908583518113,47.32690794456406,1.6964934580375015,47.39440801206413 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09982/2019_10
# start clipping
# done clipping
# 9984/10000 AOI:09983, bbox:4.160961272709847,47.2482294420209,4.260398127408573,47.31572950952097
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.160961272709847,47.2482294420209,4.260398127408573,47.31572950952097 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09983/2019_10
# start clipping
# done clipping
# 9985/10000 AOI:09984, bbox:0.39059222677213246,48.86610402029511,0.49320384003912066,48.93360408779518
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.39059222677213246,48.86610402029511,0.49320384003912066,48.93360408779518 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09984/2019_10
# start clipping
# done clipping
# 9986/10000 AOI:09985, bbox:-0.35972274198565035,46.80779225623053,-0.26110301996718976,46.8752923237306
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.35972274198565035,46.80779225623053,-0.26110301996718976,46.8752923237306 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09985/2019_10
# start clipping
# done clipping
# 9987/10000 AOI:09986, bbox:1.0267750835783955,43.78046944847698,1.1202659843645009,43.84796951597705
# planet mosaics download global_monthly_2019_10_mosaic --bbox 1.0267750835783955,43.78046944847698,1.1202659843645009,43.84796951597705 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09986/2019_10
# start clipping
# done clipping
# 9988/10000 AOI:09987, bbox:-4.560247261267456,48.56442254427677,-4.458249133477876,48.631922611776844
# planet mosaics download global_monthly_2019_10_mosaic --bbox -4.560247261267456,48.56442254427677,-4.458249133477876,48.631922611776844 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09987/2019_10
# start clipping
# done clipping
# 9989/10000 AOI:09988, bbox:4.219056220949619,49.26995748543416,4.322505260600927,49.33745755293423
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.219056220949619,49.26995748543416,4.322505260600927,49.33745755293423 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09988/2019_10
# start clipping
# done clipping
# 9990/10000 AOI:09989, bbox:-0.6807887177481717,44.855703283740816,-0.5855687116944399,44.923203351240886
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.6807887177481717,44.855703283740816,-0.5855687116944399,44.923203351240886 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09989/2019_10
# start clipping
# done clipping
# 9991/10000 AOI:09990, bbox:0.8200330957696167,45.01545383646187,0.9155183644802576,45.08295390396194
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.8200330957696167,45.01545383646187,0.9155183644802576,45.08295390396194 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09990/2019_10
# start clipping
# done clipping
# 9992/10000 AOI:09991, bbox:9.349417574678085,42.82737632260787,9.441454109348022,42.89487639010794
# planet mosaics download global_monthly_2019_10_mosaic --bbox 9.349417574678085,42.82737632260787,9.441454109348022,42.89487639010794 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09991/2019_10
# start clipping
# done clipping
# 9993/10000 AOI:09992, bbox:4.883130730290264,44.60332704644863,4.977936156937573,44.670827113948704
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.883130730290264,44.60332704644863,4.977936156937573,44.670827113948704 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09992/2019_10
# start clipping
# done clipping
# 9994/10000 AOI:09993, bbox:0.9260729077270291,47.088411052840314,1.0252110168446138,47.155911120340384
# planet mosaics download global_monthly_2019_10_mosaic --bbox 0.9260729077270291,47.088411052840314,1.0252110168446138,47.155911120340384 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09993/2019_10
# start clipping
# done clipping
# 9995/10000 AOI:09994, bbox:6.246003332830122,49.03341745334118,6.348959614698326,49.10091752084125
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.246003332830122,49.03341745334118,6.348959614698326,49.10091752084125 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09994/2019_10
# start clipping
# done clipping
# 9996/10000 AOI:09995, bbox:4.484035831138114,43.70195946204812,4.577404214453903,43.76945952954819
# planet mosaics download global_monthly_2019_10_mosaic --bbox 4.484035831138114,43.70195946204812,4.577404214453903,43.76945952954819 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09995/2019_10
# start clipping
# done clipping
# 9997/10000 AOI:09996, bbox:2.792655423302268,49.64216581191205,2.8968930878114385,49.70966587941212
# planet mosaics download global_monthly_2019_10_mosaic --bbox 2.792655423302268,49.64216581191205,2.8968930878114385,49.70966587941212 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09996/2019_10
# start clipping
# done clipping
# 9998/10000 AOI:09997, bbox:-0.7863038244071792,43.07189662207717,-0.6939009304756443,43.13939668957724
# planet mosaics download global_monthly_2019_10_mosaic --bbox -0.7863038244071792,43.07189662207717,-0.6939009304756443,43.13939668957724 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09997/2019_10
# start clipping
# done clipping
# 9999/10000 AOI:09998, bbox:6.369024684332337,47.314388733952626,6.468585964111443,47.381888801452696
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.369024684332337,47.314388733952626,6.468585964111443,47.381888801452696 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09998/2019_10
# start clipping
# done clipping
# 10000/10000 AOI:09999, bbox:6.509059927601979,45.9186940542721,6.606087609091158,45.98619412177217
# planet mosaics download global_monthly_2019_10_mosaic --bbox 6.509059927601979,45.9186940542721,6.606087609091158,45.98619412177217 --dest ../data/planet/france/sherrie10k/temp_monthly_mosaics/09999/2019_10
# start clipping
# done clipping

# %%
pd.DataFrame({
    "image_id": bbox_names_list,
    "image_shape": img_shapes
}).to_csv('../data/planet/france/sherrie10k/bbox10k_2500px_shapes.csv', index=False)

# %% [markdown]
# # Check results

# %%
import numpy as np
import imageio
import matplotlib.pyplot as plt

# %%
# after renaming
renamed = imageio.imread('../data/planet/france/sherrie10k/monthly_mosaics_renamed/09999_2019_07_L15-1061E-1318N.tif')
print(renamed.shape)
plt.imshow(np.moveaxis(renamed[:3,:,:], 0, -1))
plt.show()
# Out:
# (4, 4096, 4096)

# %%
# after clipping
clipped = imageio.imread('../data/planet/france/sherrie10k/temp_monthly_mosaics_renamed_clipped/09999_2019_07_L15-1061E-1318N.tif')
print(clipped.shape)
plt.imshow(clipped[:,:,:3])
plt.show()
# Out:
# (271, 271, 4)

# %%
# after merging
final = imageio.imread('../data/planet/france/sherrie10k/monthly_mosaics_renamed_clipped_merged/2019_07/09999_2019_07.tif')
print(final.shape)
plt.imshow(final[:,:,:3])
plt.show()
# Out:
# (271, 271, 4)

# %%
# after merging
final = imageio.imread('../data/planet/france/sherrie10k/monthly_mosaics_renamed_clipped_merged/2019_04/09999_2019_04.tif')
print(final.shape)
plt.imshow(final[:,:,:3])
plt.show()
# Out:
# (271, 271, 4)

# %%
# after merging
final = imageio.imread('../data/planet/india/monthly_mosaics_renamed_clipped_merged/00172_2019_09.tif')
print(final.shape)
plt.imshow(final[:,:,:3])
plt.show()
# Out:
# (331, 331, 4)
