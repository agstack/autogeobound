# %%
"""
Expects a csv file with image id, maxlat, maxlon, minlat, minlon of each satellite image
Expects json files as a folder with the polygons parsed from the shapefile
Expects images for overlaying masks on images

"""

import json
import numpy as np
import pandas as pd
import sys
import os
import cv2
import imageio
import csv
import matplotlib.pyplot as plt
from PIL import Image
import os
from collections import defaultdict

# %% [markdown]
# # Helper functions

# %%
def create_empty_overlays(grid, orig_images_dir, prefix='', suffix='', n=100):
    """
    Initiate empty masks and original images into the output folder based on the
    
    Args:
        grid (list): information from csv, so the empty masks to be overwritten later
    """
    for index in range(len(grid.keys())):
        image_id = str(grid[index]['image_id']).zfill(5)
        if image_id >= str(n).zfill(5):
            break
            
        im_name = os.path.join(orig_images_dir, str(prefix) + str(image_id) + str(suffix) + '.tif')
        orig_image = cv2.imread(im_name)
        overlay_path = os.path.join(base_dir, overlay_folder, str(image_id) + '.jpeg')
        cv2.imwrite(overlay_path, orig_image)

def create_dict_parcels(shp_dict):
    """
    Put the found fields from the parsed json into dict of image ids
    Args:
        shp_dict (dict): json dict containing the polygon fields

    Returns:
        dict: contains image id to polygons
    """
    dict_parcels = defaultdict(list) 
    for sh_index, sh in enumerate(shp_dict['features']):
        id_list = sh['properties']['image_id']
        for image_id in id_list:
            dict_parcels[image_id].append(sh)
    return dict_parcels

def scale_coords(shape_size, geom, grid, index):
    """
    scales the polygons lat/lon to pixel 
    Args:
        shape_size (tuple): size of the image to be scaled to
        geom (polygon): field polygon
        grid (list): values of min/max lat/lon for each image id
        index (int): Index of each image id in grid

    Returns:
        list: scaled coordinates
    """
    w, h = shape_size
    min_lat, min_lon, max_lat, max_lon = grid[index]['min_lat'], grid[index]['min_lon'], \
        grid[index]['max_lat'], grid[index]['max_lon']
    x = geom[:,0]
    y = geom[:,1]
    scale_lon = w/(max_lon - min_lon)
    scale_lat = h/(max_lat-min_lat)
    scaled_x = (x - min_lon) * scale_lon # lon-> x, lat->y
    scaled_y = h - ((y - min_lat) * scale_lat)
    if any(val > w for val in scaled_x) or any(val > h for val in scaled_y) \
        or any(val < 0 for val in scaled_x) or any (val < 0 for val in scaled_y):
        return np.concatenate([scaled_x[:,None], scaled_y[:,None]],axis=1)
    return np.concatenate([scaled_x[:,None], scaled_y[:,None]],axis=1)

# %% [markdown]
# # Setup

# %%
def get_grid(df):
    """
    Read the CSV file containing minmax lat/lon and stores it to a 2D list

    Args:
        df: pandas dataframe of bounding boxes

    Returns:
        list: contains the imag_id and lat/long information
    """
    grid = dict()
    keys = ['max_lat', 'max_lon', 'min_lat', 'min_lon']

    for index, row in df.iterrows():
        if index not in grid:
            grid[index] = dict()
        grid[index]['image_id'] = row['image_id']
        grid[index]['max_lat'] = float(row['max_lat'])
        grid[index]['max_lon'] = float(row['max_lon'])
        grid[index]['min_lat'] = float(row['min_lat'])
        grid[index]['min_lon'] = float(row['min_lon'])
        
    return grid

# %%
# ======================== USER SETUP ======================== #
# Directories to read the necessary files from
base_dir = '../data/planet/senegal/'
label_folder = 'extent_labels/'
overlay_folder = 'overlays/'

csv_file = os.path.join(base_dir, 'bbox_tiles_overlap.csv')
json_file = '../data/planet/senegal/json_polys/bbox_tiles_0_3293.json'
orig_images_dir = os.path.join(base_dir, 'monthly_mosaics_renamed_clipped_merged', '2019_10')

year_month = '_2019_10'
thickness = 2
# ============================================================ #

df = pd.read_csv(csv_file)
df['image_id'] = df['image_id'].astype(str).str.zfill(5)
grid = get_grid(df)

# %% [markdown]
# # Run label generation

# %%
# create output directory if not exist
if os.path.exists(os.path.join(base_dir, label_folder)) == False:
    os.makedirs(os.path.join(base_dir, label_folder))
if os.path.exists(os.path.join(base_dir, overlay_folder)) == False:
    os.makedirs(os.path.join(base_dir, overlay_folder))

# %%
create_empty_overlays(grid, orig_images_dir, suffix='_2019_10', n=500)
# TODO: pull planet imagery

# %%
parcels_dict['00060']
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-16.326418183999976, 14.256584086000032],
#      [-16.326550617999942, 14.254791002000047],
#      [-16.326688599999954, 14.254806400000064],
#      [-16.326857099999927, 14.254830900000059],
#      [-16.32734839999995, 14.255017400000042],
#      [-16.32752739999995, 14.255101500000023],
#      [-16.327609499999937, 14.255176400000039],
#      [-16.327742599999965, 14.255442300000027],
#      [-16.327770899999962, 14.255611600000066],
#      [-16.327795399999957, 14.255646300000024],
#      [-16.327842999999973, 14.255667800000026],
#      [-16.327955199999963, 14.255695200000048],
#      [-16.32800199999997, 14.255717900000036],
#      [-16.32804169999997, 14.255749000000037],
#      [-16.328069399999947, 14.25579010000007],
#      [-16.32814869999993, 14.256083100000069],
#      [-16.328127199999926, 14.256249800000035],
#      [-16.328093099999933, 14.25634400000007],
#      [-16.32802719999995, 14.256457500000067],
#      [-16.32788009999996, 14.256616500000064],
#      [-16.327683699999966, 14.256695900000068],
#      [-16.327556499999957, 14.256713500000046],
#      [-16.327341699999977, 14.256702700000062],
#      [-16.327309399999933, 14.256690900000024],
#      [-16.327258299999983, 14.256653400000062],
#      [-16.327234699999963, 14.256645700000036],
#      [-16.326886799999954, 14.256655800000033],
#      [-16.32684569999998, 14.25664930000005],
#      [-16.326706799999954, 14.256570000000067],
#      [-16.326632099999927, 14.256540500000028],
#      [-16.32659129999996, 14.256535900000074],
#      [-16.326499199999944, 14.256551600000023],
#      [-16.326402799999983, 14.256612400000051],
#      [-16.326418183999976, 14.256584086000032]]]},
#   'properties': {'Name': '5_05_02',
#    'Shape_Leng': 687.034985051,
#    'Shape_Area': 7.1877363043,
#    'x_long': -16.3272,
#    'y_lat': 14.2559,
#    'YIELDS_Ton': '',
#    'Village_Nu': 5,
#    'HH_Number': 5,
#    'Field_Numb': 2,
#    'V_HH': '5_5',
#    'LINK_DIST': 2098.46448132,
#    'Prop_Name': '5_5_2',
#    'crop_grown': 1,
#    'crop_gro_1': '2',
#    'crop_gro_2': '1',
#    'crop_gro_3': '2',
#    'PC_2019': '1',
#    'PC_2018': '1',
#    'PC_2017': '1',
#    'PC_2016': '1',
#    'image_id': ['00060']}},
#  {'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-16.326427899999942, 14.256561300000044],
#      [-16.326213999999936, 14.256628900000067],
#      [-16.325994299999934, 14.256580500000041],
#      [-16.325706999999966, 14.25649500000003],
#      [-16.325450199999977, 14.256489100000067],
#      [-16.325102499999957, 14.25636110000005],
#      [-16.325016999999946, 14.256322800000078],
#      [-16.325010299999974, 14.256048500000077],
#      [-16.325089399999968, 14.255850900000041],
#      [-16.325055599999928, 14.255589400000076],
#      [-16.325055599999928, 14.25525760000005],
#      [-16.325069699999972, 14.25490700000006],
#      [-16.32518129999994, 14.254855900000052],
#      [-16.325305699999944, 14.254836800000078],
#      [-16.32545689999995, 14.254613500000062],
#      [-16.325805899999978, 14.254485800000054],
#      [-16.32620049999997, 14.254613500000062],
#      [-16.326542899999936, 14.254773100000023],
#      [-16.326427899999942, 14.256561300000044]]]},
#   'properties': {'Name': '5_06_01',
#    'Shape_Leng': 698.266965407,
#    'Shape_Area': 7.89362935285,
#    'x_long': -16.3258,
#    'y_lat': 14.2556,
#    'YIELDS_Ton': '',
#    'Village_Nu': 5,
#    'HH_Number': 6,
#    'Field_Numb': 1,
#    'V_HH': '5_6',
#    'LINK_DIST': 2002.64402875,
#    'Prop_Name': '5_6_1',
#    'crop_grown': 1,
#    'crop_gro_1': '2',
#    'crop_gro_2': '1',
#    'crop_gro_3': '2',
#    'PC_2019': '1',
#    'PC_2018': '2',
#    'PC_2017': '2',
#    'PC_2016': '1',
#    'image_id': ['00060', '00141']}}]

# %%
count_parcels = defaultdict(int)
num_fields_parsed = 0

# read multiple json files
print('Read json', json_file)

# open the saved json file for the found parcels in the images 
with open(json_file) as f:
    shp_dict = json.load(f)

# create dictionary of polygons in each image for fast indexing
parcels_dict = create_dict_parcels(shp_dict)

# find the polygons of each image and plot them
for index in range(len(grid.keys())):

    image_id = grid[index]['image_id']
    polys = []
    if image_id in parcels_dict:
        img = imageio.imread(os.path.join(orig_images_dir, str(image_id) + year_month + '.tif'))
        shape_size = (img.shape[0], img.shape[1])
        extent_path = os.path.join(base_dir, label_folder, str(image_id) + '.png')
        extent_label = np.zeros(shape_size)

        for sh_index, sh in enumerate(parcels_dict[image_id]):
            count_parcels[image_id] += 1 
            for coord_idx in range(len(sh['geometry']['coordinates'])):
                geom = np.array(sh['geometry']['coordinates'][coord_idx])
                try:
                    geom_fixed = scale_coords(shape_size, geom, grid, index)
                except:
                    print("Exception in image {}".format(image_id))
                    print(geom)
                pts = geom_fixed.astype(int)
                cv2.fillPoly(extent_label, [pts], color=2)
                polys.append(pts)

        # Save the extent label
        cv2.polylines(extent_label, polys, True, color=1, thickness=thickness)
        cv2.imwrite(extent_path, extent_label)

        # Saves the overlay file
        overlay_path = os.path.join(base_dir, overlay_folder, str(image_id) + '.jpeg')
        orig_image = cv2.imread(os.path.join(orig_images_dir, str(image_id) + year_month + '.tif'))
        cv2.imwrite(overlay_path, orig_image)
        orig_image = cv2.imread(overlay_path)
        cv2.polylines(orig_image, polys, True, color=(255,255,255), thickness=thickness)
        cv2.imwrite(overlay_path, orig_image)
        print('saved image ', image_id)

    # save a small summary of number of parcels in each image
#     if start == 0:
#         open_mode = 'w'
#     else:
#         open_mode = 'a'
#     with open(os.path.join(base_dir, 'json_polys', 'parcel_in_image_count_1250px.csv'), open_mode) as csvfile:
#         writer = csv.writer(csvfile)
#         writer.writerow(['image_id', 'count'])
#         for key, value in count_parcels.items():
#             writer.writerow([int(key), value])am
# Out:
# Read json ../data/planet/senegal/json_polys/bbox_tiles_0_3293.json
# saved image  00060
# saved image  00141
# saved image  00142
# saved image  00221
# saved image  00222
# saved image  00223
# saved image  00224
# saved image  00225
# saved image  00297
# saved image  00298
# saved image  00300
# saved image  00302
# saved image  00303
# saved image  00304
# saved image  00378
# saved image  00379
# saved image  00380
# saved image  00381
# saved image  00383
# saved image  00384
# saved image  00385
# saved image  00386
# saved image  00461
# saved image  00462
# saved image  01009
# saved image  01010
# saved image  01011
# saved image  01090
# saved image  01091
# saved image  01092
# saved image  01093
# saved image  01173
# saved image  01174
# saved image  01223
# saved image  01249
# saved image  01250
# saved image  01251
# saved image  01252
# saved image  01303
# saved image  01304
# saved image  01305
# saved image  01313
# saved image  01314
# saved image  01330
# saved image  01331
# saved image  01339
# saved image  01340
# saved image  01384
# saved image  01385
# saved image  01386
# saved image  01394
# saved image  01395
# saved image  01420
# saved image  01421
# saved image  01487
# saved image  01488
# saved image  01501
# saved image  01502
# saved image  01522
# saved image  01524
# saved image  01567
# saved image  01568
# saved image  01569
# saved image  01570
# saved image  01583
# saved image  01596
# saved image  01597
# saved image  01603
# saved image  01604
# saved image  01630
# saved image  01650
# Exception in image 01677
# [[[-16.10622049  14.22497131]
#   [-16.1062319   14.2249085 ]
#   [-16.1062267   14.2248899 ]
#   [-16.1062255   14.2248337 ]
#   [-16.1062      14.2247679 ]
#   [-16.1061929   14.2246691 ]
#   [-16.106214    14.2245048 ]
#   [-16.106207    14.224481  ]
#   [-16.1061888   14.224444  ]
#   [-16.1061871   14.2244143 ]
#   [-16.1061962   14.2243714 ]
#   [-16.1061954   14.2243552 ]
#   [-16.1061883   14.2243305 ]
#   [-16.1061661   14.2242953 ]
#   [-16.1061635   14.2242838 ]
#   [-16.1061661   14.2242702 ]
#   [-16.1062418   14.2240406 ]
#   [-16.1062394   14.2240279 ]
#   [-16.1062027   14.2240115 ]
#   [-16.1061854   14.2239985 ]
#   [-16.1061763   14.2239851 ]
#   [-16.1061719   14.2237107 ]
#   [-16.1061585   14.2236523 ]
#   [-16.1062562   14.2235777 ]
#   [-16.106271    14.2235824 ]
#   [-16.1062122   14.2234625 ]
#   [-16.1062233   14.2234578 ]
#   [-16.10629     14.2234601 ]
#   [-16.1063204   14.2234687 ]
#   [-16.1064709   14.2234788 ]
#   [-16.106539    14.2234635 ]
#   [-16.1066583   14.2234708 ]
#   [-16.1067335   14.2234501 ]
#   [-16.1067448   14.2234496 ]
#   [-16.1067581   14.2234531 ]
#   [-16.1067487   14.2234589 ]
#   [-16.1067436   14.2234703 ]
#   [-16.1067425   14.2234846 ]
#   [-16.1067565   14.2235292 ]
#   [-16.1067563   14.2235533 ]
#   [-16.1067499   14.2235771 ]
#   [-16.1067529   14.223661  ]
#   [-16.1067571   14.2236738 ]
#   [-16.1067693   14.2236913 ]
#   [-16.1067745   14.2237161 ]
#   [-16.1067733   14.2237275 ]
#   [-16.1067906   14.2237807 ]
#   [-16.0315459   14.2910912 ]
#   [-16.0315739   14.2910959 ]
#   [-16.0316067   14.2910934 ]
#   [-16.0316267   14.291097  ]
#   [-16.0316492   14.2910961 ]
#   [-16.0317207   14.2910612 ]
#   [-16.0317701   14.2910586 ]
#   [-16.0319644   14.290996  ]
#   [-16.0319764   14.2909861 ]
#   [-16.0319919   14.2909838 ]
#   [-16.0320047   14.2909909 ]
#   [-16.032105    14.2910786 ]
#   [-16.0322306   14.2911499 ]
#   [-16.0322565   14.2911779 ]
#   [-16.032292    14.2911996 ]
#   [-16.0323696   14.291274  ]
#   [-16.03245     14.2913144 ]
#   [-16.0325168   14.2913772 ]
#   [-16.0326141   14.291454  ]
#   [-16.0326658   14.2915034 ]
#   [-16.0328946   14.2916713 ]
#   [-16.0329181   14.2916821 ]
#   [-16.0329854   14.2917422 ]
#   [-16.0330226   14.291789  ]
#   [-16.033068    14.2918211 ]
#   [-16.0331402   14.2918997 ]
#   [-16.0332165   14.2919684 ]
#   [-16.0332617   14.2919975 ]
#   [-16.0332824   14.2920188 ]
#   [-16.0332943   14.2920417 ]
#   [-16.033403    14.2921425 ]
#   [-16.0335934   14.2923044 ]
#   [-16.0339856   14.2927119 ]
#   [-16.0340057   14.2927293 ]
#   [-16.0340595   14.2927973 ]
#   [-16.03405891  14.29279982]]]
# saved image  02169
# saved image  02170
# saved image  02240
# saved image  02248
# saved image  02250
# saved image  02321
# saved image  02410
# saved image  02411
# saved image  02416
# saved image  02417
# saved image  02418
# saved image  02419
# saved image  02490
# saved image  02491
# saved image  02493
# saved image  02497
# saved image  02498
# saved image  02499
# saved image  02500
# saved image  02571
# saved image  02572
# saved image  02577
# saved image  02578
# saved image  02579
# saved image  02580
# saved image  02581
# saved image  02652
# saved image  02660
# saved image  02661
# saved image  02696
# saved image  02697
# Exception in image 02726
# [[[-15.95319     14.1880274 ]
#   [-15.9532      14.188026  ]
#   [-15.95319006  14.18803105]
#   [-15.95319     14.1880274 ]]]
# Exception in image 02726
# [[[-15.95319006  14.18803105]
#   [-15.95319012  14.1880343 ]
#   [-15.9531882   14.188032  ]
#   [-15.95319006  14.18803105]]]
# Exception in image 02726
# [[[-15.95319012  14.1880343 ]
#   [-15.9531971   14.18804265]
#   [-15.95319035  14.18804781]
#   [-15.95319012  14.1880343 ]]]
# Exception in image 02726
# [[[-15.95319035  14.18804781]
#   [-15.95319077  14.18807154]
#   [-15.9531828   14.1880634 ]
#   [-15.9531867   14.1880506 ]
#   [-15.95319035  14.18804781]]]
# Exception in image 02726
# [[[-15.95319077  14.18807154]
#   [-15.9531919   14.1880727 ]
#   [-15.9532024   14.1880743 ]
#   [-15.9532048   14.1880595 ]
#   [-15.9532035   14.1880503 ]
#   [-15.9531971   14.18804265]
#   [-15.9532071   14.188035  ]
#   [-15.9532766   14.1880116 ]
#   [-15.9535145   14.1878713 ]
#   [-15.9540113   14.1874605 ]
#   [-15.9541362   14.1873761 ]
#   [-15.9542286   14.1873308 ]
#   [-15.9542725   14.1873257 ]
#   [-15.954273    14.1873504 ]
#   [-15.9543238   14.1873667 ]
#   [-15.6507756   13.6019171 ]
#   [-15.6508107   13.6017987 ]
#   [-15.6508397   13.6016548 ]
#   [-15.650867    13.6014154 ]
#   [-15.6509018   13.60128   ]
#   [-15.6509037   13.6012308 ]
#   [-15.6509354   13.601141  ]
#   [-15.65093445  13.60102613]
#   [-15.6509365   13.6010303 ]]]
# saved image  04860
# saved image  04861
# saved image  04913
# saved image  04914
# saved image  04941
# saved image  05137
# saved image  05144
# saved image  05189
# saved image  05190
# saved image  05191
# saved image  05217
# saved image  05218
# saved image  05223
# saved image  05224
# saved image  05225
# saved image  05226
# saved image  05227
# saved image  05228
# saved image  05271
# saved image  05284
# saved image  05285
# saved image  05298
# saved image  05299
# saved image  05304
# saved image  05305
# saved image  05306
# saved image  05307
# saved image  05308
# saved image  05309
# saved image  05365
# saved image  05366
# saved image  05379
# saved image  05380
# saved image  05387
# saved image  05388
# saved image  05446
# saved image  06778
# saved image  06779
# saved image  06780
# saved image  06858
# saved image  06859
# saved image  06860
# saved image  06861
# saved image  06862
# saved image  06932
# saved image  06933
# saved image  06934
# saved image  06939
# saved image  06940
# saved image  06941
# saved image  06996
# saved image  07013
# saved image  07014
# saved image  07015
# saved image  07016
# saved image  07076
# saved image  07077
# saved image  07078
# saved image  07079
# saved image  07091
# saved image  07092
# saved image  07094
# saved image  07095
# saved image  07096
# saved image  07151
# saved image  07152
# saved image  07158
# saved image  07159
# saved image  07160
# saved image  07163
# saved image  07164
# saved image  07165
# saved image  07170
# saved image  07171
# saved image  07172
# saved image  07173
# saved image  07232
# saved image  07233
# saved image  07234
# saved image  07240
# saved image  07241
# saved image  07242
# saved image  07243
# saved image  07244
# saved image  07245
# saved image  07246
# saved image  07251
# saved image  07252
# saved image  07253
# saved image  07254
# saved image  07313
# saved image  07314
# saved image  07315
# saved image  07323
# saved image  07325
# saved image  07392
# saved image  07393
# saved image  07394
# saved image  07395
# saved image  07473
# saved image  07474
# saved image  07475
# saved image  07554
# saved image  07555
# saved image  07556
# saved image  07557
# saved image  08796
# saved image  08797
# saved image  08876
# saved image  08877
# saved image  08878
# saved image  08957
# saved image  08958
# saved image  08959
# saved image  09667
# saved image  09748
# Exception in image 09749
# [[[-14.97719753  13.92177201]
#   [-14.9772036   13.921762  ]
#   [-14.9772046   13.9217732 ]
#   [-14.97719753  13.92177201]]]
# Exception in image 09749
# [[[-14.97719753  13.92177201]
#   [-14.9771965   13.9217737 ]
#   [-14.9771954   13.9217842 ]
#   [-14.9771892   13.9217936 ]
#   [-14.9771928   13.921802  ]
#   [-14.9771517   13.9219053 ]
#   [-14.97713534  13.92200925]
#   [-14.9767756   13.9219574 ]
#   [-14.9766775   13.9219336 ]
#   [-14.9762573   13.9218971 ]
#   [-14.9762342   13.9218898 ]
#   [-14.9761952   13.9218625 ]
#   [-14.9761801   13.9218448 ]
#   [-14.976174    13.921789  ]
#   [-14.9761986   13.9216571 ]
#   [-14.9762268   13.9216101 ]
#   [-14.9762847   13.9215907 ]
#   [-14.9763189   13.9215915 ]
#   [-14.9766679   13.9216826 ]
#   [-14.97719753  13.92177201]]]
#   [-14.6379369   14.316508  ]
#   [-14.6378091   14.3164289 ]
#   [-14.637628    14.3163796 ]
#   [-14.6373718   14.3162519 ]
#   [-14.6372807   14.3162367 ]
#   [-14.637258    14.3162236 ]
#   [-14.6372402   14.3161986 ]
#   [-14.63723131  14.31617584]]]
# saved image  12231
# saved image  12232
# saved image  12310
# saved image  12311
# saved image  12312
# saved image  12313
# saved image  12314
# saved image  12393
# saved image  12394
# saved image  12398
# saved image  12399
# saved image  12474
# saved image  12475
# saved image  12476
# saved image  12479
# saved image  12480
# saved image  12557
# saved image  12562
# saved image  12563
# saved image  12566
# saved image  12567
# saved image  12635
# saved image  12636
# saved image  12637
# saved image  12644
# saved image  12647
# saved image  12648
# saved image  12649
# saved image  12681
# saved image  12682
# saved image  12683
# saved image  12717
# saved image  12718
# saved image  12719
# saved image  12726
# saved image  12727
# saved image  12729
# saved image  12730
# saved image  12731
# saved image  12763
# saved image  12764
# saved image  12765
# saved image  12766
# saved image  12767
# saved image  12799
# saved image  12800
# saved image  12845
# saved image  12846
# saved image  12847
# saved image  12848
# saved image  12886
# saved image  12927
# saved image  12928
# saved image  12929
# saved image  12968
# saved image  13050
# saved image  13053
# saved image  13064
# saved image  13133
# saved image  13135
# saved image  13146
# saved image  13147
# saved image  13148
# saved image  13215
# saved image  13216
# saved image  13217
# saved image  13227
# saved image  13228
# saved image  13229
# saved image  13282
# saved image  13284
# saved image  13285
# saved image  13298
# saved image  13299
# saved image  13311
# saved image  13364
# saved image  13365
# saved image  13366
# saved image  13392
# saved image  13393
# saved image  13445
# saved image  13446
# saved image  13447
# saved image  13448
# saved image  13449
# saved image  13450
# saved image  13474
# saved image  13528
# saved image  13529
# saved image  13530
# saved image  13611
# saved image  13612
# saved image  13613
# saved image  13678
# saved image  13690
# saved image  13691
# saved image  13692
# saved image  13693
# saved image  13694
# saved image  13760
# saved image  13761
# saved image  13772
# saved image  13773
# saved image  13774
# saved image  13775
# saved image  13843
# saved image  13844
# saved image  13845
# saved image  13854
# saved image  13855
# saved image  13856
# saved image  13857
# saved image  13860
# saved image  13927
# saved image  13938
# saved image  13940
# saved image  14022
# saved image  14207
# saved image  14288
# saved image  14289
# saved image  14372
# saved image  14373
# saved image  14454
# saved image  14455
# saved image  14534
# saved image  14535
# saved image  14537

# %% [markdown]
# ## Verify labels

# %%
fig, ax = plt.subplots(1,3, figsize=(12,4))

image_id = np.random.choice(df['image_id'].values)
ymonth = '2019_09'

mask = imageio.imread('../data/planet/senegal/monthly_mosaics_renamed_clipped_merged/{}/{}.tif'.format(
    ymonth, image_id + '_' + ymonth))
ax[0].imshow(mask)
ax[0].set_title('Planet image, {}'.format(ymonth))

extent = imageio.imread('../data/planet/senegal/extent_labels/{}.png'.format(image_id))
ax[1].imshow(extent, cmap='Greys_r', interpolation='nearest', vmin=0, vmax=2)
ax[1].set_title('Extent labels')

overlay = imageio.imread('../data/planet/senegal/overlays/{}.jpeg'.format(image_id))
ax[2].imshow(overlay)
ax[2].set_title('Overlay, 2019_10')

fig.suptitle("Image #: {}".format(image_id))

plt.show()
